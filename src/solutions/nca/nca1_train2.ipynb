# %%
import sys
import torch
import wandb
from pathlib import Path
sys.path.append('../..')

from solutions.nca.nca1_model import NCA1Model
from cgol.generator.uniform_density_generator import UniformDensityGenerator
from cgol.simulator.torch_simulator import TorchSimulator
from cgol.simulator.minimal_architecture_simulator import MinimalArchitectureSimulator
from cgol.simulator.derivable_minimal_architecture_simulator import DerivableMinimalArchitectureSimulator
from cgol.dataloader.dataloader_2 import Dataloader2
from cgol.loss.completion_loss2 import CompletionLoss2
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
seed = 0
width = 20
height = 20
batch_size = 500
dtype = torch.float
preprocess_device = 'cpu'
model_device = 'cuda'

dataloader_simulator = MinimalArchitectureSimulator(device=preprocess_device, dtype=dtype)
#train_simulator = DerivableMinimalArchitectureSimulator(device=model_device, dtype=dtype)
train_simulator = MinimalArchitectureSimulator(device=model_device, dtype=dtype)

generator = UniformDensityGenerator(seed, preprocess_device, dtype)
dataloader = Dataloader2(generator, dataloader_simulator, batch_size, width, height, preprocess_device, model_device, dtype, 0.1)

#model = Conv1Model(device=model_device, dtype=dtype, n_hidden_layers=4, n_channels=2000, 
#                   last_activation=lambda: lambda x: torch.nn.functional.sigmoid(x-0.5)*20)
model = NCA1Model(device=model_device, dtype=dtype)
model.initialize()
lr = 0.001
betas = (0.9,0.999)
eps = 0.00000001
#weight_decay = 0
weight_decay = 0.0001
optimizer = torch.optim.Adam(model.parameters(), lr=lr, betas=betas, eps=eps, weight_decay=weight_decay)
loss_fn = torch.nn.MSELoss()
#loss_fn = CompletionLoss2()
n_solving_steps = 60
gradient_clipping = True

config = {
    "dataloader": dataloader.get_config(),
    "model": model.get_config(),
    "optimizer": {
        "type": type(optimizer).__name__,
        "lr": lr,
        "betas": betas,
        "eps": eps,
        "weight_decay": weight_decay
    },
    "loss": {
        "type": type(loss_fn).__name__
    },
    "gradient_clipping": gradient_clipping,
    "n_solving_steps": n_solving_steps
}

config
# Out:
# /workspaces/cgol/src/solutions/nca/../../solutions/nca/nca1_model.py:81: FutureWarning: `nn.init.xavier_uniform` is now deprecated in favor of `nn.init.xavier_uniform_`.
#   init_weight_f(self.conv_start.weight)
# /workspaces/cgol/src/solutions/nca/../../solutions/nca/nca1_model.py:86: FutureWarning: `nn.init.xavier_uniform` is now deprecated in favor of `nn.init.xavier_uniform_`.
#   init_weight_f(self.conv_end.weight)
# {'dataloader': {'type': 'Dataloader1',
#   'generator': {'type': 'UniformDensityGenerator', 'seed': 0},
#   'width': 20,
#   'height': 20,
#   'batch_size': 500,
#   'min_change_threshold': 0.1,
#   'max_sequence_age': 150},
#  'model': {'type': 'NCA1Model',
#   'is_toroidal': False,
#   'perception_size': 3,
#   'activation': 'type',
#   'last_activation': 'type',
#   'hidden_size': 100,
#   'n_hidden_layers': 0,
#   'n_channels': 100,
#   'n_parameters': 102301,
#   'weight_init': 'xavier_uniform',
#   'bias_init': 'zeros_',
#   'batch_norm': True},
#  'optimizer': {'type': 'Adam',
#   'lr': 0.001,
#   'betas': (0.9, 0.999),
#   'eps': 1e-08,
#   'weight_decay': 0.0001},
#  'loss': {'type': 'MSELoss'},
#  'gradient_clipping': True,
#  'n_solving_steps': 60}

# %%
wandb_log = True

# %%
def safe_state(path: str, 
               model: NCA1Model, 
               optimizer: torch.nn.Module, 
               dataloader, 
               run_state: dict):
    save_state = {
        'model_state': model.state_dict(),
        'optimizer_state': optimizer.state_dict(),
        'dataloader_state': dataloader.get_state(),
        'run_state': run_state
    }
    torch.save(save_state, path)

def train(
        run_state: dict,
        model: torch.nn.Module, 
        dataloader, 
        optimizer: torch.optim.Optimizer, 
        simulator: TorchSimulator,
        loss_fn: torch.nn.Module, 
        checkpoint_path: Path, 
        max_steps: int=300000, 
        patience: int=75000) -> dict:
    run_state.update({
        'step': 0,
        'best_loss_step': 0,
        'best_accuracy_micro_step': 0,
        'best_accuracy_macro_step': 0,
        'loss': sys.float_info.max,
        'accuracy_micro': 0,
        'accuracy_macro': 0,
        'best_loss': sys.float_info.max,
        'best_accuracy_micro': 0,
        'best_accuracy_macro': 0,
        'best_end_state_accuracy_micro': 0,
        'best_end_state_accuracy_macro': 0
    } | run_state)

    safe_state(checkpoint_path/'initial.ckpt', model, optimizer, dataloader, run_state)
    
    if wandb_log:
        wandb.init('llottenbach', 'cgol', config={
            "config": config
        })

    model.train()
    try:
        for batch in dataloader:
            optimizer.zero_grad()

            target_end_state = batch[0]
            target_initial_state = batch[1]

            model_input: torch.Tensor = model.init_model_input(target_end_state)
            
            run_state['loss'] = 1.

            for i_solving_step in range(n_solving_steps):

                model_output = model.forward(model_input)
                predicted_initial_state: torch.Tensor = model.output_batch_from_model_output(model_output)
                #predicted_end_state = simulator.step_batch_tensor(predicted_initial_state)
                predicted_end_state = simulator.step_batch_tensor((predicted_initial_state >= 0.5) * 1.)
                model_input = model.model_input_from_model_output(model_output, target_end_state)

                # metrics
                #initial_state_loss = loss_fn(predicted_initial_state, target_initial_state)
                #end_state_loss = loss_fn(predicted_end_state, target_end_state)
                run_state['loss'] = run_state['loss'] + loss_fn(predicted_initial_state, target_initial_state)
                
                run_state['initial_state_accuracy_micro'] = (((predicted_initial_state >= 0.5) == target_initial_state).sum()
                    / (target_initial_state.shape[0] * target_initial_state.shape[1] * target_initial_state.shape[2]))
                run_state['initial_state_accuracy_macro'] = (((predicted_initial_state >= 0.5) == target_initial_state).all((-1,-2)).sum()
                    / (target_initial_state.shape[0]))
                
                run_state['end_state_accuracy_micro'] = (((predicted_end_state >= 0.5) == target_end_state).sum()
                    / (target_end_state.shape[0] * target_end_state.shape[1] * target_end_state.shape[2]))
                run_state['end_state_accuracy_macro'] = (((predicted_end_state >= 0.5) == target_end_state).all((-1,-2)).sum()
                    / (target_end_state.shape[0]))

                run_state['accuracy_micro'] = run_state['initial_state_accuracy_micro']
                run_state['accuracy_macro'] = run_state['initial_state_accuracy_macro']
                
                if run_state['best_loss'] > run_state['loss'] / (i_solving_step + 1):
                    run_state['best_loss'] = run_state['loss'].clone().detach() / (i_solving_step + 1)
                    run_state['best_loss_step'] = run_state['step']
                    safe_state(checkpoint_path/'best_loss.chkpt', model, optimizer, dataloader, run_state)
                if run_state['best_accuracy_micro'] < run_state['accuracy_micro']:
                    run_state['best_accuracy_micro'] = run_state['accuracy_micro'].detach().clone()
                    run_state['best_accuracy_micro_step'] = run_state['step']
                    safe_state(checkpoint_path/'best_acc_micro.chkpt', model, optimizer, dataloader, run_state)
                if run_state['best_accuracy_macro'] < run_state['accuracy_macro']:
                    run_state['best_accuracy_macro'] = run_state['accuracy_macro'].detach().clone()
                    run_state['best_accuracy_macro_step'] = run_state['step']
                    safe_state(checkpoint_path/'best_acc_macro.chkpt', model, optimizer, dataloader, run_state)
                if run_state['best_end_state_accuracy_micro'] < run_state['end_state_accuracy_micro']:
                    run_state['best_end_state_accuracy_micro'] = run_state['end_state_accuracy_micro'].detach().clone()
                    run_state['best_end_state_accuracy_micro_step'] = run_state['step']
                    safe_state(checkpoint_path/'best_end_acc_micro.chkpt', model, optimizer, dataloader, run_state)
                if run_state['best_end_state_accuracy_macro'] < run_state['end_state_accuracy_macro']:
                    run_state['best_end_state_accuracy_macro'] = run_state['end_state_accuracy_macro'].detach().clone()
                    run_state['best_end_state_accuracy_macro_step'] = run_state['step']
                    safe_state(checkpoint_path/'best_end_acc_macro.chkpt', model, optimizer, dataloader, run_state)
                                
                # log
                print(run_state)
                print(f'step: {run_state["step"]:7d},',
                    f'loss: {run_state["loss"]:1.16f},',
                    f'accuracy-micro: {run_state["accuracy_micro"]:1.16f},',
                    f'accuracy-macro: {run_state["accuracy_macro"]:1.16f}')
                if wandb_log:
                    wandb.log({
                        'train/loss': run_state['loss'] / (i_solving_step + 1),
                        'train/accuracy-micro': run_state['accuracy_micro'],
                        'train/accuracy-macro': run_state['accuracy_macro'],
                        'train/initial-state/accuracy-micro': run_state['initial_state_accuracy_micro'],
                        'train/initial-state/accuracy-macro': run_state['initial_state_accuracy_macro'],
                        'train/end-state/accuracy-micro': run_state['end_state_accuracy_micro'],
                        'train/end-state/accuracy-macro': run_state['end_state_accuracy_macro'],

                        # dataloader
                        'dataloader/batch_age/min': dataloader.sequence_ages.min(),
                        'dataloader/batch_age/max': dataloader.sequence_ages.max(),
                        'dataloader/batch_age/median': dataloader.sequence_ages.float().median(),
                        'dataloader/batch_age/mean': dataloader.sequence_ages.float().mean(),
                        'dataloader/batch_age/std': dataloader.sequence_ages.float().std(),
                        'dataloader/batch_diffs_per_cell/min': dataloader.batch_diffs_per_cell.min(),
                        'dataloader/batch_diffs_per_cell/max': dataloader.batch_diffs_per_cell.max(),
                        'dataloader/batch_diffs_per_cell/median': dataloader.batch_diffs_per_cell.median(),
                        'dataloader/batch_diffs_per_cell/mean': dataloader.batch_diffs_per_cell.mean(),
                        'dataloader/batch_diffs_per_cell/std': dataloader.batch_diffs_per_cell.std(),
                    },
                    run_state['step'])

                # stop condition
                if (max_steps <= run_state['step']
                    or run_state['best_loss_step'] + patience <= run_state['step']
                    or run_state['best_accuracy_micro_step'] + patience <= run_state['step']
                    or run_state['best_accuracy_macro_step'] + patience <= run_state['step']):

                    safe_state(checkpoint_path/'stop.chkpt', model, optimizer, dataloader, run_state)
                    raise KeyboardInterrupt('Stop Condition reached')
                
                run_state['step'] += 1
                
            # optimize
            run_state['loss'] = run_state['loss'] / n_solving_steps
            run_state['loss'].backward()
            if gradient_clipping:
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
    except BaseException as e:
        safe_state(checkpoint_path/'error.chkpt', model, optimizer, dataloader, run_state)
        wandb.finish()
        raise e

    return run_state

# %%
if wandb_log:
    wandb.login()
# Out:
# wandb: Currently logged in as: lukas-lottenbach (llottenbach-nlp) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
run_checkpoint_path = Path('nca1_train2')
run_checkpoint_path.mkdir(exist_ok=True)
run_state = {}
train(run_state, model, dataloader, optimizer, train_simulator, loss_fn, run_checkpoint_path,
      max_steps=300000*n_solving_steps, patience=75000*n_solving_steps)
# 40 solving steps -> 60
# https://wandb.ai/llottenbach/cgol/runs/w4uyxscu
# Out:
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/workspaces/cgol/src/solutions/nca/wandb/run-20251215_025004-w4uyxscu</code>
# Syncing run <strong><a href='https://wandb.ai/llottenbach/cgol/runs/w4uyxscu' target="_blank">wild-cosmos-27</a></strong> to <a href='https://wandb.ai/llottenbach/cgol' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/llottenbach/cgol' target="_blank">https://wandb.ai/llottenbach/cgol</a>
#  View run at <a href='https://wandb.ai/llottenbach/cgol/runs/w4uyxscu' target="_blank">https://wandb.ai/llottenbach/cgol/runs/w4uyxscu</a>
# {'step': 0, 'best_loss_step': 0, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(1.2512, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.6110, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(1.2512, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.6110, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:       0, loss: 1.2512276172637939, accuracy-micro: 0.6110050082206726, accuracy-macro: 0.0000000000000000
# {'step': 1, 'best_loss_step': 1, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(1.5240, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.4494, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.7620, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.4494, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6462, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:       1, loss: 1.5239504575729370, accuracy-micro: 0.4494299888610840, accuracy-macro: 0.0000000000000000
# {'step': 2, 'best_loss_step': 2, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(1.7945, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5674, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.5982, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5674, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.7088, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:       2, loss: 1.7944910526275635, accuracy-micro: 0.5673899650573730, accuracy-macro: 0.0000000000000000
# {'step': 3, 'best_loss_step': 3, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(2.0742, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5533, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.5185, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5533, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6854, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:       3, loss: 2.0741615295410156, accuracy-micro: 0.5532850027084351, accuracy-macro: 0.0000000000000000
# {'step': 4, 'best_loss_step': 4, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(2.3430, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5694, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.4686, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5694, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.7105, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:       4, loss: 2.3429977893829346, accuracy-micro: 0.5693649649620056, accuracy-macro: 0.0000000000000000
# {'step': 5, 'best_loss_step': 5, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(2.6187, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5548, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.4365, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5548, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6939, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:       5, loss: 2.6187176704406738, accuracy-micro: 0.5548099875450134, accuracy-macro: 0.0000000000000000
# {'step': 6, 'best_loss_step': 6, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(2.8947, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5403, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.4135, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5403, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6938, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:       6, loss: 2.8946926593780518, accuracy-micro: 0.5403450131416321, accuracy-macro: 0.0000000000000000
# {'step': 7, 'best_loss_step': 7, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(3.1757, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5160, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3970, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5160, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6858, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:       7, loss: 3.1757211685180664, accuracy-micro: 0.5160300135612488, accuracy-macro: 0.0000000000000000
# {'step': 8, 'best_loss_step': 8, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(3.4570, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5039, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3841, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5039, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6929, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:       8, loss: 3.4570097923278809, accuracy-micro: 0.5038650035858154, accuracy-macro: 0.0000000000000000
# {'step': 9, 'best_loss_step': 9, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(3.7427, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.4946, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3743, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.4946, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6888, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:       9, loss: 3.7426750659942627, accuracy-micro: 0.4945899844169617, accuracy-macro: 0.0000000000000000
# {'step': 10, 'best_loss_step': 10, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(4.0233, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5164, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3658, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5164, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.7023, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      10, loss: 4.0233178138732910, accuracy-micro: 0.5163899660110474, accuracy-macro: 0.0000000000000000
# {'step': 11, 'best_loss_step': 11, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(4.3087, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5012, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3591, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5012, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6897, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      11, loss: 4.3087148666381836, accuracy-micro: 0.5011649727821350, accuracy-macro: 0.0000000000000000
# {'step': 12, 'best_loss_step': 12, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(4.5938, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5031, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3534, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5031, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6966, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      12, loss: 4.5938301086425781, accuracy-micro: 0.5031250119209290, accuracy-macro: 0.0000000000000000
# {'step': 13, 'best_loss_step': 13, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(4.8788, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5059, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3485, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5059, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6941, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      13, loss: 4.8788342475891113, accuracy-micro: 0.5059499740600586, accuracy-macro: 0.0000000000000000
# {'step': 14, 'best_loss_step': 14, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(5.1625, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5147, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3442, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5147, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6977, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      14, loss: 5.1624937057495117, accuracy-micro: 0.5147050023078918, accuracy-macro: 0.0000000000000000
# {'step': 15, 'best_loss_step': 15, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(5.4487, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5016, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3405, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5016, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6913, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      15, loss: 5.4486532211303711, accuracy-micro: 0.5016399621963501, accuracy-macro: 0.0000000000000000
# {'step': 16, 'best_loss_step': 16, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(5.7360, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5080, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3374, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5080, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6999, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      16, loss: 5.7360496520996094, accuracy-micro: 0.5080499649047852, accuracy-macro: 0.0000000000000000
# {'step': 17, 'best_loss_step': 17, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(6.0228, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5070, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3346, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5070, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.7006, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      17, loss: 6.0228066444396973, accuracy-micro: 0.5070250034332275, accuracy-macro: 0.0000000000000000
# {'step': 18, 'best_loss_step': 18, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(6.3075, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5144, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3320, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5144, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6975, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      18, loss: 6.3075265884399414, accuracy-micro: 0.5144149661064148, accuracy-macro: 0.0000000000000000
# {'step': 19, 'best_loss_step': 19, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(6.5918, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5115, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3296, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5115, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6949, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      19, loss: 6.5918045043945312, accuracy-micro: 0.5115399956703186, accuracy-macro: 0.0000000000000000
# {'step': 20, 'best_loss_step': 20, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(6.8753, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5155, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3274, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5155, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6993, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      20, loss: 6.8753161430358887, accuracy-micro: 0.5155050158500671, accuracy-macro: 0.0000000000000000
# {'step': 21, 'best_loss_step': 21, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(7.1596, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5135, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3254, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5135, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6976, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      21, loss: 7.1595954895019531, accuracy-micro: 0.5134800076484680, accuracy-macro: 0.0000000000000000
# {'step': 22, 'best_loss_step': 22, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(7.4434, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5170, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3236, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5170, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6975, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      22, loss: 7.4433608055114746, accuracy-micro: 0.5169999599456787, accuracy-macro: 0.0000000000000000
# {'step': 23, 'best_loss_step': 23, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(7.7276, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5143, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3220, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5143, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6928, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      23, loss: 7.7276358604431152, accuracy-micro: 0.5143449902534485, accuracy-macro: 0.0000000000000000
# {'step': 24, 'best_loss_step': 24, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(8.0102, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5191, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3204, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5191, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6959, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      24, loss: 8.0102415084838867, accuracy-micro: 0.5190899968147278, accuracy-macro: 0.0000000000000000
# {'step': 25, 'best_loss_step': 25, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(8.2955, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5100, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3191, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5100, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6937, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      25, loss: 8.2955150604248047, accuracy-micro: 0.5100349783897400, accuracy-macro: 0.0000000000000000
# {'step': 26, 'best_loss_step': 26, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(8.5797, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5144, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3178, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5144, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6924, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      26, loss: 8.5796966552734375, accuracy-micro: 0.5144099593162537, accuracy-macro: 0.0000000000000000
# {'step': 27, 'best_loss_step': 27, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(8.8650, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5144, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3166, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5144, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6969, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      27, loss: 8.8649911880493164, accuracy-micro: 0.5143849849700928, accuracy-macro: 0.0000000000000000
# {'step': 28, 'best_loss_step': 28, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(9.1489, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5151, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3155, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5151, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6902, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      28, loss: 9.1488504409790039, accuracy-micro: 0.5150949954986572, accuracy-macro: 0.0000000000000000
# {'step': 29, 'best_loss_step': 29, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(9.4335, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5131, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3145, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5131, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6933, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      29, loss: 9.4335021972656250, accuracy-micro: 0.5131149888038635, accuracy-macro: 0.0000000000000000
# {'step': 30, 'best_loss_step': 30, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(9.7171, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5149, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3135, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5149, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6908, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      30, loss: 9.7170915603637695, accuracy-micro: 0.5148850083351135, accuracy-macro: 0.0000000000000000
# {'step': 31, 'best_loss_step': 31, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(10.0017, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5132, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3126, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5132, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6901, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      31, loss: 10.0017375946044922, accuracy-micro: 0.5131549835205078, accuracy-macro: 0.0000000000000000
# {'step': 32, 'best_loss_step': 32, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(10.2860, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5114, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3117, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5114, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6899, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      32, loss: 10.2860126495361328, accuracy-micro: 0.5113800168037415, accuracy-macro: 0.0000000000000000
# {'step': 33, 'best_loss_step': 33, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(10.5710, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5123, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3109, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5123, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6880, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      33, loss: 10.5710105895996094, accuracy-micro: 0.5122649669647217, accuracy-macro: 0.0000000000000000
# {'step': 34, 'best_loss_step': 34, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(10.8545, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5147, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3101, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5147, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6894, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      34, loss: 10.8544845581054688, accuracy-micro: 0.5146650075912476, accuracy-macro: 0.0000000000000000
# {'step': 35, 'best_loss_step': 35, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(11.1392, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5152, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3094, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5152, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6877, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      35, loss: 11.1391754150390625, accuracy-micro: 0.5151500105857849, accuracy-macro: 0.0000000000000000
# {'step': 36, 'best_loss_step': 36, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(11.4231, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5123, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3087, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5123, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6887, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      36, loss: 11.4230995178222656, accuracy-micro: 0.5122550129890442, accuracy-macro: 0.0000000000000000
# {'step': 37, 'best_loss_step': 37, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(11.7075, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5146, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3081, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5146, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6884, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      37, loss: 11.7075424194335938, accuracy-micro: 0.5145849585533142, accuracy-macro: 0.0000000000000000
# {'step': 38, 'best_loss_step': 38, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(11.9922, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5112, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3075, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5112, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6900, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      38, loss: 11.9921817779541016, accuracy-micro: 0.5112299919128418, accuracy-macro: 0.0000000000000000
# {'step': 39, 'best_loss_step': 39, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(12.2761, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5155, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3069, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5155, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6899, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      39, loss: 12.2761087417602539, accuracy-micro: 0.5155199766159058, accuracy-macro: 0.0000000000000000
# {'step': 40, 'best_loss_step': 40, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(12.5603, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5136, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3063, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5136, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6896, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      40, loss: 12.5602931976318359, accuracy-micro: 0.5135549902915955, accuracy-macro: 0.0000000000000000
# {'step': 41, 'best_loss_step': 41, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(12.8440, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5165, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3058, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5165, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6901, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      41, loss: 12.8440399169921875, accuracy-micro: 0.5164700150489807, accuracy-macro: 0.0000000000000000
# {'step': 42, 'best_loss_step': 42, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(13.1275, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5145, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3053, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5145, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6861, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      42, loss: 13.1275396347045898, accuracy-micro: 0.5144850015640259, accuracy-macro: 0.0000000000000000
# {'step': 43, 'best_loss_step': 43, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(13.4117, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5148, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3048, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5148, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6910, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      43, loss: 13.4116525650024414, accuracy-micro: 0.5148199796676636, accuracy-macro: 0.0000000000000000
# {'step': 44, 'best_loss_step': 44, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(13.6953, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5139, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3043, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5139, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6883, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      44, loss: 13.6952600479125977, accuracy-micro: 0.5138800144195557, accuracy-macro: 0.0000000000000000
# {'step': 45, 'best_loss_step': 45, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(13.9786, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5174, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3039, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5174, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6926, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      45, loss: 13.9786043167114258, accuracy-micro: 0.5174199938774109, accuracy-macro: 0.0000000000000000
# {'step': 46, 'best_loss_step': 46, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(14.2630, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5123, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3035, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5123, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6876, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      46, loss: 14.2630081176757812, accuracy-micro: 0.5123149752616882, accuracy-macro: 0.0000000000000000
# {'step': 47, 'best_loss_step': 47, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(14.5465, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5182, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3031, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5182, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6915, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      47, loss: 14.5464534759521484, accuracy-micro: 0.5181599855422974, accuracy-macro: 0.0000000000000000
# {'step': 48, 'best_loss_step': 48, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(14.8303, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5146, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3027, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5146, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6876, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      48, loss: 14.8303451538085938, accuracy-micro: 0.5146449804306030, accuracy-macro: 0.0000000000000000
# {'step': 49, 'best_loss_step': 49, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(15.1137, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5183, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3023, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5183, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6898, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      49, loss: 15.1136960983276367, accuracy-micro: 0.5183199644088745, accuracy-macro: 0.0000000000000000
# {'step': 50, 'best_loss_step': 50, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(15.3975, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5141, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3019, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5141, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6867, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      50, loss: 15.3974971771240234, accuracy-micro: 0.5140849947929382, accuracy-macro: 0.0000000000000000
# {'step': 51, 'best_loss_step': 51, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(15.6811, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5165, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3016, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5165, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6894, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      51, loss: 15.6810960769653320, accuracy-micro: 0.5165100097656250, accuracy-macro: 0.0000000000000000
# {'step': 52, 'best_loss_step': 52, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(15.9649, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.5149, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.3012, device='cuda:0'), 'best_accuracy_micro': tensor(0.6110, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.7745, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.5149, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.6865, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 0}
# step:      52, loss: 15.9649171829223633, accuracy-micro: 0.5149049758911133, accuracy-macro: 0.0000000000000000
# ...
# step:    2202, loss: 9.5394878387451172, accuracy-micro: 0.7657600045204163, accuracy-macro: 0.0000000000000000
# {'step': 2203, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(9.7368, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7657, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7657, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8094, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2203, loss: 9.7367582321166992, accuracy-micro: 0.7657200098037720, accuracy-macro: 0.0000000000000000
# {'step': 2204, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(9.9340, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8093, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2204, loss: 9.9340267181396484, accuracy-micro: 0.7658199667930603, accuracy-macro: 0.0000000000000000
# {'step': 2205, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(10.1313, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8094, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2205, loss: 10.1312980651855469, accuracy-micro: 0.7657799720764160, accuracy-macro: 0.0000000000000000
# {'step': 2206, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(10.3286, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8093, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2206, loss: 10.3285675048828125, accuracy-micro: 0.7657899856567383, accuracy-macro: 0.0000000000000000
# {'step': 2207, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(10.5258, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8094, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2207, loss: 10.5258388519287109, accuracy-micro: 0.7657600045204163, accuracy-macro: 0.0000000000000000
# {'step': 2208, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(10.7231, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8092, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2208, loss: 10.7231101989746094, accuracy-micro: 0.7657899856567383, accuracy-macro: 0.0000000000000000
# {'step': 2209, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(10.9204, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7657, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7657, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8094, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2209, loss: 10.9203805923461914, accuracy-micro: 0.7657449841499329, accuracy-macro: 0.0000000000000000
# {'step': 2210, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(11.1176, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8093, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2210, loss: 11.1176481246948242, accuracy-micro: 0.7657749652862549, accuracy-macro: 0.0000000000000000
# {'step': 2211, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(11.3149, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8095, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2211, loss: 11.3149175643920898, accuracy-micro: 0.7657849788665771, accuracy-macro: 0.0000000000000000
# {'step': 2212, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(11.5122, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8093, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2212, loss: 11.5121860504150391, accuracy-micro: 0.7657949924468994, accuracy-macro: 0.0000000000000000
# {'step': 2213, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(11.7095, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8093, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2213, loss: 11.7094583511352539, accuracy-micro: 0.7657600045204163, accuracy-macro: 0.0000000000000000
# {'step': 2214, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(11.9067, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8093, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2214, loss: 11.9067287445068359, accuracy-micro: 0.7657699584960938, accuracy-macro: 0.0000000000000000
# {'step': 2215, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(12.1040, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8094, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2215, loss: 12.1039981842041016, accuracy-micro: 0.7657699584960938, accuracy-macro: 0.0000000000000000
# {'step': 2216, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(12.3013, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8093, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2216, loss: 12.3012657165527344, accuracy-micro: 0.7657549977302551, accuracy-macro: 0.0000000000000000
# {'step': 2217, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(12.4985, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8094, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2217, loss: 12.4985351562500000, accuracy-micro: 0.7657649517059326, accuracy-macro: 0.0000000000000000
# {'step': 2218, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(12.6958, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8093, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2218, loss: 12.6958065032958984, accuracy-micro: 0.7657999992370605, accuracy-macro: 0.0000000000000000
# {'step': 2219, 'best_loss_step': 2159, 'best_accuracy_micro_step': 2112, 'best_accuracy_macro_step': 0, 'loss': tensor(12.8931, device='cuda:0', grad_fn=<AddBackward0>), 'accuracy_micro': tensor(0.7658, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2145, device='cuda:0'), 'best_accuracy_micro': tensor(0.7697, device='cuda:0'), 'best_accuracy_macro': 0, 'best_end_state_accuracy_micro': tensor(0.8129, device='cuda:0'), 'best_end_state_accuracy_macro': 0, 'initial_state_accuracy_micro': tensor(0.7658, device='cuda:0'), 'initial_state_accuracy_macro': tensor(0., device='cuda:0'), 'end_state_accuracy_micro': tensor(0.8093, device='cuda:0'), 'end_state_accuracy_macro': tensor(0., device='cuda:0'), 'best_end_state_accuracy_micro_step': 2166}
# step:    2219, loss: 12.8930778503417969, accuracy-micro: 0.7657749652862549, accuracy-macro: 0.0000000000000000

# %%
wandb.finish()

# %%
safe_state(run_checkpoint_path/'finish.chkpt', model, optimizer, dataloader, run_state)
