# %%
import sys
import torch
import wandb
from pathlib import Path
sys.path.append('../..')

from solutions.convolution.conv1_model import Conv1Model
from cgol.generator.uniform_density_generator import UniformDensityGenerator
from cgol.simulator.torch_simulator import TorchSimulator
from cgol.simulator.minimal_architecture_simulator import MinimalArchitectureSimulator
from cgol.simulator.derivable_minimal_architecture_simulator import DerivableMinimalArchitectureSimulator
from cgol.dataloader.dataloader_2 import Dataloader2
from cgol.loss.completion_loss import CompletionLoss
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
seed = 0
width = 20
height = 20
batch_size = 500
dtype = torch.float
preprocess_device = 'cpu'
model_device = 'cuda'

dataloader_simulator = MinimalArchitectureSimulator(device=preprocess_device, dtype=dtype)
train_simulator = DerivableMinimalArchitectureSimulator(device=model_device, dtype=dtype)

generator = UniformDensityGenerator(seed, preprocess_device, dtype)
dataloader = Dataloader2(generator, dataloader_simulator, batch_size, width, height, preprocess_device, model_device, dtype, 0.1)

model = Conv1Model(device=model_device, dtype=dtype, n_hidden_layers=4, n_channels=2000, 
                   last_activation=lambda: lambda x: torch.nn.functional.sigmoid(x-0.5)*20)
model.initialize()
lr = 0.001
betas = (0.9,0.999)
eps = 0.00000001
weight_decay = 0.0001
optimizer = torch.optim.Adam(model.parameters(), lr=lr, betas=betas, eps=eps, weight_decay=weight_decay)
loss_fn = CompletionLoss()

config = {
    "dataloader": dataloader.get_config(),
    "model": model.get_config(),
    "optimizer": {
        "type": "Adam",
        "lr": lr,
        "betas": betas,
        "eps": eps,
        "weight_decay": weight_decay
    },
    "loss": {
        "type": "CompletionLoss"
    }
}

config
# Out:
# /workspaces/cgol/src/solutions/convolution/../../solutions/convolution/conv1_model.py:73: FutureWarning: `nn.init.xavier_uniform` is now deprecated in favor of `nn.init.xavier_uniform_`.
#   init_weight_f(self.conv_start.weight)
# /workspaces/cgol/src/solutions/convolution/../../solutions/convolution/conv1_model.py:76: FutureWarning: `nn.init.xavier_uniform` is now deprecated in favor of `nn.init.xavier_uniform_`.
#   init_weight_f(hidden_conf.weight)
# /workspaces/cgol/src/solutions/convolution/../../solutions/convolution/conv1_model.py:78: FutureWarning: `nn.init.xavier_uniform` is now deprecated in favor of `nn.init.xavier_uniform_`.
#   init_weight_f(self.conv_end.weight)
# {'dataloader': {'type': 'Dataloader1',
#   'generator': {'type': 'UniformDensityGenerator', 'seed': 0},
#   'width': 20,
#   'height': 20,
#   'batch_size': 500,
#   'min_change_threshold': 0.1,
#   'max_sequence_age': 150},
#  'model': {'type': 'Conv1Model',
#   'is_toroidal': False,
#   'kernel_size': 5,
#   'activation': 'type',
#   'last_activation': 'function',
#   'n_hidden_layers': 4,
#   'n_channels': 2000,
#   'n_parameters': 102001,
#   'weight_init': 'xavier_uniform',
#   'bias_init': 'zeros_'},
#  'optimizer': {'type': 'Adam',
#   'lr': 0.001,
#   'betas': (0.9, 0.999),
#   'eps': 1e-08,
#   'weight_decay': 0.0001},
#  'loss': {'type': 'CompletionLoss'}}

# %%
wandb_log = True

# %%
def safe_state(path: str, 
               model: torch.nn.Module, 
               optimizer: torch.nn.Module, 
               dataloader, 
               run_state: dict):
    save_state = {
        'model_state': model.state_dict(),
        'optimizer_state': optimizer.state_dict(),
        'dataloader_state': dataloader.get_state(),
        'run_state': run_state
    }
    torch.save(save_state, path)

def train(
        run_state: dict,
        model: torch.nn.Module, 
        dataloader, 
        optimizer: torch.optim.Optimizer, 
        derivable_simulator: TorchSimulator,
        loss_fn: torch.nn.Module, 
        checkpoint_path: Path, 
        max_steps: int=300000, 
        patience: int=75000) -> dict:
    run_state.update({
        'step': 0,
        'best_loss_step': 0,
        'best_accuracy_micro_step': 0,
        'best_accuracy_macro_step': 0,
        'loss': sys.float_info.max,
        'accuracy_micro': 0,
        'accuracy_macro': 0,
        'best_loss': sys.float_info.max,
        'best_accuracy_micro': 0,
        'best_accuracy_macro': 0
    } | run_state)

    safe_state(checkpoint_path/'initial.ckpt', model, optimizer, dataloader, run_state)
    
    if wandb_log:
        wandb.init('llottenbach', 'cgol', config={
            "config": config
        })

    model.train()
    try:
        for batch in dataloader:
            optimizer.zero_grad()
            output = model.forward(batch[0])
            output = derivable_simulator.step_batch_tensor(output)

            # metrics
            run_state['loss'] = loss_fn(output, batch[0])
            run_state['accuracy_micro'] = (((output >= 0.5) == batch[1]).sum()
                / (output.shape[0] * output.shape[1] * output.shape[2]))
            run_state['accuracy_macro'] = (((output >= 0.5) == batch[1]).all((-1,-2)).sum()
                / (output.shape[0]))
            
            if run_state['best_loss'] > run_state['loss']:
                run_state['best_loss'] = run_state['loss'].clone().detach()
                run_state['best_loss_step'] = run_state['step']
                safe_state(checkpoint_path/'best_loss.chkpt', model, optimizer, dataloader, run_state)
            if run_state['best_accuracy_micro'] < run_state['accuracy_micro']:
                run_state['best_accuracy_micro'] = run_state['accuracy_micro'].detach().clone()
                run_state['best_accuracy_micro_step'] = run_state['step']
                safe_state(checkpoint_path/'best_acc_micro.chkpt', model, optimizer, dataloader, run_state)
            if run_state['best_accuracy_macro'] < run_state['accuracy_macro']:
                run_state['best_accuracy_macro'] = run_state['accuracy_macro'].detach().clone()
                run_state['best_accuracy_macro_step'] = run_state['step']
                safe_state(checkpoint_path/'best_acc_macro.chkpt', model, optimizer, dataloader, run_state)
            
            # optimize
            run_state['loss'].backward()
            optimizer.step()
            
            # log
            print(run_state)
            print(f'step: {run_state["step"]:7d},',
                f'loss: {run_state["loss"]:1.16f},',
                f'accuracy-micro: {run_state["accuracy_micro"]:1.16f},',
                f'accuracy-macro: {run_state["accuracy_macro"]:1.16f}')
            if wandb_log:
                wandb.log({
                    'train/loss': run_state['loss'],
                    'train/accuracy-micro': run_state['accuracy_micro'],
                    'train/accuracy-macro': run_state['accuracy_macro'],
                    # dataloader
                    'dataloader/batch_age/min': dataloader.sequence_ages.min(),
                    'dataloader/batch_age/max': dataloader.sequence_ages.max(),
                    'dataloader/batch_age/median': dataloader.sequence_ages.float().median(),
                    'dataloader/batch_age/mean': dataloader.sequence_ages.float().mean(),
                    'dataloader/batch_age/std': dataloader.sequence_ages.float().std(),
                    'dataloader/batch_diffs_per_cell/min': dataloader.batch_diffs_per_cell.min(),
                    'dataloader/batch_diffs_per_cell/max': dataloader.batch_diffs_per_cell.max(),
                    'dataloader/batch_diffs_per_cell/median': dataloader.batch_diffs_per_cell.median(),
                    'dataloader/batch_diffs_per_cell/mean': dataloader.batch_diffs_per_cell.mean(),
                    'dataloader/batch_diffs_per_cell/std': dataloader.batch_diffs_per_cell.std(),
                },
                run_state['step'])

            # stop condition
            if (max_steps <= run_state['step']
                or run_state['best_loss_step'] + patience <= run_state['step']
                or run_state['best_accuracy_micro_step'] + patience <= run_state['step']
                or run_state['best_accuracy_macro_step'] + patience <= run_state['step']):

                safe_state(checkpoint_path/'stop.chkpt', model, optimizer, dataloader, run_state)
                break
            
            run_state['step'] += 1
    except BaseException as e:
        safe_state(checkpoint_path/'error.chkpt', model, optimizer, dataloader, run_state)
        raise e

    return run_state

# %%
if wandb_log:
    wandb.login()
# Out:
# wandb: Currently logged in as: lukas-lottenbach (llottenbach-nlp) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
run_checkpoint_path = Path('conv1_train_on_endstate_2')
run_checkpoint_path.mkdir(exist_ok=True)
run_state = {}
train(run_state, model, dataloader, optimizer, train_simulator, loss_fn, run_checkpoint_path)
# changed activation to sigmoid(x-0.5)*20
# https://wandb.ai/llottenbach/cgol/runs/km17cktc
# Out:
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/workspaces/cgol/src/solutions/convolution/wandb/run-20251203_202942-km17cktc</code>
# Syncing run <strong><a href='https://wandb.ai/llottenbach/cgol/runs/km17cktc' target="_blank">upbeat-sunset-21</a></strong> to <a href='https://wandb.ai/llottenbach/cgol' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/llottenbach/cgol' target="_blank">https://wandb.ai/llottenbach/cgol</a>
#  View run at <a href='https://wandb.ai/llottenbach/cgol/runs/km17cktc' target="_blank">https://wandb.ai/llottenbach/cgol/runs/km17cktc</a>
# {'step': 0, 'best_loss_step': 0, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(18.2824, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.4592, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2824, device='cuda:0'), 'best_accuracy_micro': tensor(0.4592, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       0, loss: 18.2824440002441406, accuracy-micro: 0.4591600000858307, accuracy-macro: 0.0000000000000000
# {'step': 1, 'best_loss_step': 0, 'best_accuracy_micro_step': 1, 'best_accuracy_macro_step': 0, 'loss': tensor(19.5900, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6297, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2824, device='cuda:0'), 'best_accuracy_micro': tensor(0.6297, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       1, loss: 19.5900154113769531, accuracy-micro: 0.6296899914741516, accuracy-macro: 0.0000000000000000
# {'step': 2, 'best_loss_step': 0, 'best_accuracy_micro_step': 2, 'best_accuracy_macro_step': 0, 'loss': tensor(22.5949, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6600, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2824, device='cuda:0'), 'best_accuracy_micro': tensor(0.6600, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       2, loss: 22.5948753356933594, accuracy-micro: 0.6599900126457214, accuracy-macro: 0.0000000000000000
# {'step': 3, 'best_loss_step': 0, 'best_accuracy_micro_step': 3, 'best_accuracy_macro_step': 0, 'loss': tensor(21.8095, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7006, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2824, device='cuda:0'), 'best_accuracy_micro': tensor(0.7006, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       3, loss: 21.8095302581787109, accuracy-micro: 0.7006250023841858, accuracy-macro: 0.0000000000000000
# {'step': 4, 'best_loss_step': 0, 'best_accuracy_micro_step': 4, 'best_accuracy_macro_step': 0, 'loss': tensor(21.1382, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7174, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2824, device='cuda:0'), 'best_accuracy_micro': tensor(0.7174, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       4, loss: 21.1382236480712891, accuracy-micro: 0.7173749804496765, accuracy-macro: 0.0000000000000000
# {'step': 5, 'best_loss_step': 0, 'best_accuracy_micro_step': 5, 'best_accuracy_macro_step': 0, 'loss': tensor(20.1089, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7273, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2824, device='cuda:0'), 'best_accuracy_micro': tensor(0.7273, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       5, loss: 20.1089038848876953, accuracy-micro: 0.7272599935531616, accuracy-macro: 0.0000000000000000
# {'step': 6, 'best_loss_step': 0, 'best_accuracy_micro_step': 6, 'best_accuracy_macro_step': 0, 'loss': tensor(19.7014, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7413, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2824, device='cuda:0'), 'best_accuracy_micro': tensor(0.7413, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       6, loss: 19.7014102935791016, accuracy-micro: 0.7413150072097778, accuracy-macro: 0.0000000000000000
# {'step': 7, 'best_loss_step': 0, 'best_accuracy_micro_step': 7, 'best_accuracy_macro_step': 0, 'loss': tensor(18.7205, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7450, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2824, device='cuda:0'), 'best_accuracy_micro': tensor(0.7450, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       7, loss: 18.7205238342285156, accuracy-micro: 0.7449849843978882, accuracy-macro: 0.0000000000000000
# {'step': 8, 'best_loss_step': 0, 'best_accuracy_micro_step': 8, 'best_accuracy_macro_step': 0, 'loss': tensor(18.4734, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7575, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2824, device='cuda:0'), 'best_accuracy_micro': tensor(0.7575, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       8, loss: 18.4733791351318359, accuracy-micro: 0.7574650049209595, accuracy-macro: 0.0000000000000000
# {'step': 9, 'best_loss_step': 9, 'best_accuracy_micro_step': 8, 'best_accuracy_macro_step': 0, 'loss': tensor(17.3725, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7485, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(17.3725, device='cuda:0'), 'best_accuracy_micro': tensor(0.7575, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       9, loss: 17.3724937438964844, accuracy-micro: 0.7485049962997437, accuracy-macro: 0.0000000000000000
# {'step': 10, 'best_loss_step': 9, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(17.5184, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7630, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(17.3725, device='cuda:0'), 'best_accuracy_micro': tensor(0.7630, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      10, loss: 17.5183753967285156, accuracy-micro: 0.7629849910736084, accuracy-macro: 0.0000000000000000
# {'step': 11, 'best_loss_step': 11, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(16.7229, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7609, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(16.7229, device='cuda:0'), 'best_accuracy_micro': tensor(0.7630, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      11, loss: 16.7228698730468750, accuracy-micro: 0.7608799934387207, accuracy-macro: 0.0000000000000000
# {'step': 12, 'best_loss_step': 12, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(16.6990, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7551, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(16.6990, device='cuda:0'), 'best_accuracy_micro': tensor(0.7630, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      12, loss: 16.6989650726318359, accuracy-micro: 0.7550749778747559, accuracy-macro: 0.0000000000000000
# {'step': 13, 'best_loss_step': 13, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(16.4715, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7601, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(16.4715, device='cuda:0'), 'best_accuracy_micro': tensor(0.7630, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      13, loss: 16.4714603424072266, accuracy-micro: 0.7600649595260620, accuracy-macro: 0.0000000000000000
# {'step': 14, 'best_loss_step': 14, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(15.8801, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7477, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.8801, device='cuda:0'), 'best_accuracy_micro': tensor(0.7630, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      14, loss: 15.8801050186157227, accuracy-micro: 0.7477349638938904, accuracy-macro: 0.0000000000000000
# {'step': 15, 'best_loss_step': 14, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor
device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1206, loss: 16.6016254425048828, accuracy-micro: 0.7607849836349487, accuracy-macro: 0.0000000000000000
# {'step': 1207, 'best_loss_step': 510, 'best_accuracy_micro_step': 803, 'best_accuracy_macro_step': 0, 'loss': tensor(16.7859, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7508, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1207, loss: 16.7858753204345703, accuracy-micro: 0.7507500052452087, accuracy-macro: 0.0000000000000000
# {'step': 1208, 'best_loss_step': 510, 'best_accuracy_micro_step': 803, 'best_accuracy_macro_step': 0, 'loss': tensor(16.9292, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7506, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1208, loss: 16.9291992187500000, accuracy-micro: 0.7506299614906311, accuracy-macro: 0.0000000000000000
# {'step': 1209, 'best_loss_step': 510, 'best_accuracy_micro_step': 803, 'best_accuracy_macro_step': 0, 'loss': tensor(16.8890, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7530, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1209, loss: 16.8889636993408203, accuracy-micro: 0.7529699802398682, accuracy-macro: 0.0000000000000000
# {'step': 1210, 'best_loss_step': 510, 'best_accuracy_micro_step': 803, 'best_accuracy_macro_step': 0, 'loss': tensor(17.2410, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7448, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1210, loss: 17.2410449981689453, accuracy-micro: 0.7447699904441833, accuracy-macro: 0.0000000000000000
# {'step': 1211, 'best_loss_step': 510, 'best_accuracy_micro_step': 803, 'best_accuracy_macro_step': 0, 'loss': tensor(17.1215, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7477, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1211, loss: 17.1215190887451172, accuracy-micro: 0.7477299571037292, accuracy-macro: 0.0000000000000000
# {'step': 1212, 'best_loss_step': 510, 'best_accuracy_micro_step': 803, 'best_accuracy_macro_step': 0, 'loss': tensor(16.9813, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7527, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1212, loss: 16.9813003540039062, accuracy-micro: 0.7526899576187134, accuracy-macro: 0.0000000000000000
# {'step': 1213, 'best_loss_step': 510, 'best_accuracy_micro_step': 803, 'best_accuracy_macro_step': 0, 'loss': tensor(16.4829, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7542, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1213, loss: 16.4829254150390625, accuracy-micro: 0.7541949748992920, accuracy-macro: 0.0000000000000000
# {'step': 1214, 'best_loss_step': 510, 'best_accuracy_micro_step': 803, 'best_accuracy_macro_step': 0, 'loss': tensor(16.1995, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7541, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1214, loss: 16.1994743347167969, accuracy-micro: 0.7541499733924866, accuracy-macro: 0.0000000000000000
# {'step': 1215, 'best_loss_step': 510, 'best_accuracy_micro_step': 803, 'best_accuracy_macro_step': 0, 'loss': tensor(17.0252, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7487, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1215, loss: 17.0251846313476562, accuracy-micro: 0.7486999630928040, accuracy-macro: 0.0000000000000000
# {'step': 1216, 'best_loss_step': 510, 'best_accuracy_micro_step': 803, 'best_accuracy_macro_step': 0, 'loss': tensor(17.0814, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7533, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1216, loss: 17.0813751220703125, accuracy-micro: 0.7533199787139893, accuracy-macro: 0.0000000000000000
# {'step': 1217, 'best_loss_step': 510, 'best_accuracy_micro_step': 803, 'best_accuracy_macro_step': 0, 'loss': tensor(16.8557, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7710, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(15.4295, device='cuda:0'), 'best_accuracy_micro': tensor(0.7740, device='cuda:0'), 'best_accuracy_macro': 0}
# step:    1217, loss: 16.8556652069091797, accuracy-micro: 0.7710099816322327, accuracy-macro: 0.0000000000000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1467716/3175203077.py in <cell line: 0>()
#       2 run_checkpoint_path.mkdir(exist_ok=True)
#       3 run_state = {}
# ----> 4 train(run_state, model, dataloader, optimizer, train_simulator, loss_fn, run_checkpoint_path)
#       5 # changed activation to sigmoid(x-0.5)*20
#
# /tmp/ipykernel_1467716/872105964.py in train(run_state, model, dataloader, optimizer, derivable_simulator, loss_fn, checkpoint_path, max_steps, patience)
#     110     except BaseException as e:
#     111         safe_state(checkpoint_path/'error.chkpt', model, optimizer, dataloader, run_state)
# --> 112         raise e
#     113
#     114     return run_state
#
# /tmp/ipykernel_1467716/872105964.py in train(run_state, model, dataloader, optimizer, derivable_simulator, loss_fn, checkpoint_path, max_steps, patience)
#      70
#      71             # optimize
# ---> 72             run_state['loss'].backward()
#      73             optimizer.step()
#      74
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     568         return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#     569
# --> 570     def backward(
#     571         self, gradient=None, retain_graph=None, create_graph=False, inputs=None
#     572     ):
#
# KeyboardInterrupt:

# %%
wandb.finish()

# %%
safe_state(run_checkpoint_path/'finish.chkpt', model, optimizer, dataloader, run_state)
