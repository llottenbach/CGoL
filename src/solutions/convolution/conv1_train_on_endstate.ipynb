# %%
import sys
import torch
import wandb
from pathlib import Path
sys.path.append('../..')

from solutions.convolution.conv1_model import Conv1Model
from cgol.generator.uniform_density_generator import UniformDensityGenerator
from cgol.simulator.torch_simulator import TorchSimulator
from cgol.simulator.minimal_architecture_simulator import MinimalArchitectureSimulator
from cgol.simulator.derivable_minimal_architecture_simulator import DerivableMinimalArchitectureSimulator
from cgol.dataloader.dataloader_2 import Dataloader2
from cgol.loss.completion_loss import CompletionLoss
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
seed = 0
width = 20
height = 20
batch_size = 500
dtype = torch.float
preprocess_device = 'cpu'
model_device = 'cuda'

dataloader_simulator = MinimalArchitectureSimulator(device=preprocess_device, dtype=dtype)
train_simulator = DerivableMinimalArchitectureSimulator(device=model_device, dtype=dtype)

generator = UniformDensityGenerator(seed, preprocess_device, dtype)
dataloader = Dataloader2(generator, dataloader_simulator, batch_size, width, height, preprocess_device, model_device, dtype, 0.1)

model = Conv1Model(device=model_device, dtype=dtype, n_hidden_layers=4, n_channels=2000)
model.initialize()
lr = 0.001
betas = (0.9,0.999)
eps = 0.00000001
weight_decay = 0.0001
optimizer = torch.optim.Adam(model.parameters(), lr=lr, betas=betas, eps=eps, weight_decay=weight_decay)
loss_fn = CompletionLoss()

config = {
    "dataloader": dataloader.get_config(),
    "model": model.get_config(),
    "optimizer": {
        "type": "Adam",
        "lr": lr,
        "betas": betas,
        "eps": eps,
        "weight_decay": weight_decay
    },
    "loss": {
        "type": "CompletionLoss"
    }
}

config
# Out:
# /workspaces/cgol/src/solutions/convolution/../../solutions/convolution/conv1_model.py:73: FutureWarning: `nn.init.xavier_uniform` is now deprecated in favor of `nn.init.xavier_uniform_`.
#   init_weight_f(self.conv_start.weight)
# /workspaces/cgol/src/solutions/convolution/../../solutions/convolution/conv1_model.py:76: FutureWarning: `nn.init.xavier_uniform` is now deprecated in favor of `nn.init.xavier_uniform_`.
#   init_weight_f(hidden_conf.weight)
# /workspaces/cgol/src/solutions/convolution/../../solutions/convolution/conv1_model.py:78: FutureWarning: `nn.init.xavier_uniform` is now deprecated in favor of `nn.init.xavier_uniform_`.
#   init_weight_f(self.conv_end.weight)
# {'dataloader': {'type': 'Dataloader1',
#   'generator': {'type': 'UniformDensityGenerator', 'seed': 0},
#   'width': 20,
#   'height': 20,
#   'batch_size': 500,
#   'min_change_threshold': 0.1,
#   'max_sequence_age': 150},
#  'model': {'type': 'Conv1Model',
#   'is_toroidal': False,
#   'kernel_size': 5,
#   'activation': 'type',
#   'last_activation': 'type',
#   'n_hidden_layers': 4,
#   'n_channels': 2000,
#   'n_parameters': 102001,
#   'weight_init': 'xavier_uniform',
#   'bias_init': 'zeros_'},
#  'optimizer': {'type': 'Adam',
#   'lr': 0.001,
#   'betas': (0.9, 0.999),
#   'eps': 1e-08,
#   'weight_decay': 0.0001},
#  'loss': {'type': 'CompletionLoss'}}

# %%
wandb_log = True

# %%
def safe_state(path: str, 
               model: torch.nn.Module, 
               optimizer: torch.nn.Module, 
               dataloader, 
               run_state: dict):
    save_state = {
        'model_state': model.state_dict(),
        'optimizer_state': optimizer.state_dict(),
        'dataloader_state': dataloader.get_state(),
        'run_state': run_state
    }
    torch.save(save_state, path)

def train(
        run_state: dict,
        model: torch.nn.Module, 
        dataloader, 
        optimizer: torch.optim.Optimizer, 
        derivable_simulator: TorchSimulator,
        loss_fn: torch.nn.Module, 
        checkpoint_path: Path, 
        max_steps: int=300000, 
        patience: int=75000) -> dict:
    run_state.update({
        'step': 0,
        'best_loss_step': 0,
        'best_accuracy_micro_step': 0,
        'best_accuracy_macro_step': 0,
        'loss': sys.float_info.max,
        'accuracy_micro': 0,
        'accuracy_macro': 0,
        'best_loss': sys.float_info.max,
        'best_accuracy_micro': 0,
        'best_accuracy_macro': 0
    } | run_state)

    safe_state(checkpoint_path/'initial.ckpt', model, optimizer, dataloader, run_state)
    
    if wandb_log:
        wandb.init('llottenbach', 'test', config={
            "config": config
        })

    model.train()
    try:
        for batch in dataloader:
            optimizer.zero_grad()
            output = model.forward(batch[0])
            output = derivable_simulator.step_batch_tensor(output)

            # metrics
            run_state['loss'] = loss_fn(output, batch[0])
            run_state['accuracy_micro'] = (((output >= 0.5) == batch[1]).sum()
                / (output.shape[0] * output.shape[1] * output.shape[2]))
            run_state['accuracy_macro'] = (((output >= 0.5) == batch[1]).all((-1,-2)).sum()
                / (output.shape[0]))
            
            if run_state['best_loss'] > run_state['loss']:
                run_state['best_loss'] = run_state['loss'].clone().detach()
                run_state['best_loss_step'] = run_state['step']
                safe_state(checkpoint_path/'best_loss.chkpt', model, optimizer, dataloader, run_state)
            if run_state['best_accuracy_micro'] < run_state['accuracy_micro']:
                run_state['best_accuracy_micro'] = run_state['accuracy_micro'].detach().clone()
                run_state['best_accuracy_micro_step'] = run_state['step']
                safe_state(checkpoint_path/'best_acc_micro.chkpt', model, optimizer, dataloader, run_state)
            if run_state['best_accuracy_macro'] < run_state['accuracy_macro']:
                run_state['best_accuracy_macro'] = run_state['accuracy_macro'].detach().clone()
                run_state['best_accuracy_macro_step'] = run_state['step']
                safe_state(checkpoint_path/'best_acc_macro.chkpt', model, optimizer, dataloader, run_state)
            
            # optimize
            run_state['loss'].backward()
            optimizer.step()
            
            # log
            print(run_state)
            print(f'step: {run_state["step"]:7d},',
                f'loss: {run_state["loss"]:1.16f},',
                f'accuracy-micro: {run_state["accuracy_micro"]:1.16f},',
                f'accuracy-macro: {run_state["accuracy_macro"]:1.16f}')
            if wandb_log:
                wandb.log({
                    'train/loss': run_state['loss'],
                    'train/accuracy-micro': run_state['accuracy_micro'],
                    'train/accuracy-macro': run_state['accuracy_macro'],
                    # dataloader
                    'dataloader/batch_age/min': dataloader.sequence_ages.min(),
                    'dataloader/batch_age/max': dataloader.sequence_ages.max(),
                    'dataloader/batch_age/median': dataloader.sequence_ages.float().median(),
                    'dataloader/batch_age/mean': dataloader.sequence_ages.float().mean(),
                    'dataloader/batch_age/std': dataloader.sequence_ages.float().std(),
                    'dataloader/batch_diffs_per_cell/min': dataloader.batch_diffs_per_cell.min(),
                    'dataloader/batch_diffs_per_cell/max': dataloader.batch_diffs_per_cell.max(),
                    'dataloader/batch_diffs_per_cell/median': dataloader.batch_diffs_per_cell.median(),
                    'dataloader/batch_diffs_per_cell/mean': dataloader.batch_diffs_per_cell.mean(),
                    'dataloader/batch_diffs_per_cell/std': dataloader.batch_diffs_per_cell.std(),
                },
                run_state['step'])

            # stop condition
            if (max_steps <= run_state['step']
                or run_state['best_loss_step'] + patience <= run_state['step']
                or run_state['best_accuracy_micro_step'] + patience <= run_state['step']
                or run_state['best_accuracy_macro_step'] + patience <= run_state['step']):

                safe_state(checkpoint_path/'stop.chkpt', model, optimizer, dataloader, run_state)
                break
            
            run_state['step'] += 1
    except BaseException as e:
        safe_state(checkpoint_path/'error.chkpt', model, optimizer, dataloader, run_state)
        raise e

    return run_state

# %%
if wandb_log:
    wandb.login()
# Out:
# wandb: Currently logged in as: lukas-lottenbach (llottenbach-nlp) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
run_checkpoint_path = Path('conv1_train_on_endstate')
run_checkpoint_path.mkdir(exist_ok=True)
run_state = {}
train(run_state, model, dataloader, optimizer, train_simulator, loss_fn, run_checkpoint_path)
# Out:
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/workspaces/cgol/src/solutions/convolution/wandb/run-20251203_014605-n1vwbvqt</code>
# Syncing run <strong><a href='https://wandb.ai/llottenbach/test/runs/n1vwbvqt' target="_blank">comic-silence-11</a></strong> to <a href='https://wandb.ai/llottenbach/test' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/llottenbach/test' target="_blank">https://wandb.ai/llottenbach/test</a>
#  View run at <a href='https://wandb.ai/llottenbach/test/runs/n1vwbvqt' target="_blank">https://wandb.ai/llottenbach/test/runs/n1vwbvqt</a>
# {'step': 0, 'best_loss_step': 0, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(31.8478, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.4724, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.8478, device='cuda:0'), 'best_accuracy_micro': tensor(0.4724, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       0, loss: 31.8477725982666016, accuracy-micro: 0.4723699986934662, accuracy-macro: 0.0000000000000000
# {'step': 1, 'best_loss_step': 0, 'best_accuracy_micro_step': 1, 'best_accuracy_macro_step': 0, 'loss': tensor(32.3902, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6029, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.8478, device='cuda:0'), 'best_accuracy_micro': tensor(0.6029, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       1, loss: 32.3902282714843750, accuracy-micro: 0.6029300093650818, accuracy-macro: 0.0000000000000000
# {'step': 2, 'best_loss_step': 2, 'best_accuracy_micro_step': 2, 'best_accuracy_macro_step': 0, 'loss': tensor(31.2091, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6114, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6114, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       2, loss: 31.2090587615966797, accuracy-micro: 0.6113699674606323, accuracy-macro: 0.0000000000000000
# {'step': 3, 'best_loss_step': 2, 'best_accuracy_micro_step': 2, 'best_accuracy_macro_step': 0, 'loss': tensor(77.9429, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.5213, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6114, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       3, loss: 77.9429244995117188, accuracy-micro: 0.5212849974632263, accuracy-macro: 0.0000000000000000
# {'step': 4, 'best_loss_step': 2, 'best_accuracy_micro_step': 2, 'best_accuracy_macro_step': 0, 'loss': tensor(37.3629, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6036, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6114, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       4, loss: 37.3629188537597656, accuracy-micro: 0.6036049723625183, accuracy-macro: 0.0000000000000000
# {'step': 5, 'best_loss_step': 2, 'best_accuracy_micro_step': 5, 'best_accuracy_macro_step': 0, 'loss': tensor(33.3604, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6356, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6356, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       5, loss: 33.3604011535644531, accuracy-micro: 0.6356199979782104, accuracy-macro: 0.0000000000000000
# {'step': 6, 'best_loss_step': 2, 'best_accuracy_micro_step': 6, 'best_accuracy_macro_step': 0, 'loss': tensor(36.4277, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6428, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6428, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       6, loss: 36.4276924133300781, accuracy-micro: 0.6428149938583374, accuracy-macro: 0.0000000000000000
# {'step': 7, 'best_loss_step': 2, 'best_accuracy_micro_step': 7, 'best_accuracy_macro_step': 0, 'loss': tensor(37.8065, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6435, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6435, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       7, loss: 37.8064956665039062, accuracy-micro: 0.6435349583625793, accuracy-macro: 0.0000000000000000
# {'step': 8, 'best_loss_step': 2, 'best_accuracy_micro_step': 8, 'best_accuracy_macro_step': 0, 'loss': tensor(38.8566, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6493, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6493, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       8, loss: 38.8566284179687500, accuracy-micro: 0.6492549777030945, accuracy-macro: 0.0000000000000000
# {'step': 9, 'best_loss_step': 2, 'best_accuracy_micro_step': 8, 'best_accuracy_macro_step': 0, 'loss': tensor(37.8945, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6409, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6493, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       9, loss: 37.8944702148437500, accuracy-micro: 0.6409149765968323, accuracy-macro: 0.0000000000000000
# {'step': 10, 'best_loss_step': 2, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(37.8742, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6499, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6499, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      10, loss: 37.8742446899414062, accuracy-micro: 0.6498749852180481, accuracy-macro: 0.0000000000000000
# {'step': 11, 'best_loss_step': 2, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(36.0233, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6484, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6499, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      11, loss: 36.0232887268066406, accuracy-micro: 0.6483500003814697, accuracy-macro: 0.0000000000000000
# {'step': 12, 'best_loss_step': 2, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(34.3470, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6451, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6499, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      12, loss: 34.3470191955566406, accuracy-micro: 0.6450949907302856, accuracy-macro: 0.0000000000000000
# {'step': 13, 'best_loss_step': 2, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(32.3060, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6494, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(31.2091, device='cuda:0'), 'best_accuracy_micro': tensor(0.6499, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      13, loss: 32.3060302734375000, accuracy-micro: 0.6493949890136719, accuracy-macro: 0.0000000000000000
# {'step': 14, 'best_loss_step': 14, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(29.1740, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6411, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(29.1740, device='cuda:0'), 'best_accuracy_micro': tensor(0.6499, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      14, loss: 29.1739711761474609, accuracy-micro: 0.6411449909210205, accuracy-macro: 0.0000000000000000
# {'step': 15, 'best_loss_step': 15, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(26.9250, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6422, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(26.9250, device='cuda:0'), 'best_accuracy_micro': tensor(0.6499, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      15, loss: 26.9250469207763672, accuracy-micro: 0.6422199606895447, accuracy-macro: 0.0000000000000000
# {'step': 16, 'best_loss_step': 15, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(32.6225, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6177, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(26.9250, device='cuda:0'), 'best_accuracy_micro': tensor(0.6499, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      16, loss: 32.6225280761718750, accuracy-micro: 0.6176899671554565, accuracy-macro: 0.0000000000000000
# {'step': 17, 'best_loss_step': 17, 'best_accuracy_micro_step': 10, 'best_accuracy_macro_step': 0, 'loss': tensor(25.7039, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6481, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(25.7039, device='cuda:0'), 'best_accuracy_micro': tensor(0.6499, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      17, loss: 25.7038650512695312, accuracy-micro: 0.6481249928474426, accuracy-macro: 0.0000000000000000
# {'step': 18, 'best_loss_step': 17, 'best_accuracy_micro_step': 18, 'best_accuracy_macro_step': 0, 'loss': tensor(25.9664, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6517, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(25.7039, device='cuda:0'), 'best_accuracy_micro': tensor(0.6517, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      18, loss: 25.9664402008056641, accuracy-micro: 0.6516849994659424, accuracy-macro: 0.0000000000000000
# {'step': 19, 'best_loss_step': 17, 'best_accuracy_micro_step': 18, 'best_accuracy_macro_step': 0, 'loss': tensor(27.0676, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6469, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(25.7039, device='cuda:0'), 'best_accuracy_micro': tensor(0.6517, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      19, loss: 27.0676383972167969, accuracy-micro: 0.6468849778175354, accuracy-macro: 0.0000000000000000
# {'step': 20, 'best_loss_step': 17, 'best_accuracy_micro_step': 18, 'best_accuracy_macro_step': 0, 'loss': tensor(27.6378, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6499, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(25.7039, device='cuda:0'), 'best_accuracy_micro': tensor(0.6517, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      20, loss: 27.6378440856933594, accuracy-micro: 0.6498699784278870, accuracy-macro: 0.0000000000000000
# {'step': 21, 'best_loss_step': 17, 'best_accuracy_micro_step': 18, 'best_accuracy_macro_step': 0, 'loss': tensor(26.7207, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6455, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(25.7039, device='cuda:0'), 'best_accuracy_micro': tensor(0.6517, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      21, loss: 26.7206649780273438, accuracy-micro: 0.6454699635505676, accuracy-macro: 0.0000000000000000
# {'step': 22, 'best_loss_step': 17, 'best_accuracy_micro_step': 22, 'best_accuracy_macro_step': 0, 'loss': tensor(26.1795, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6519, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(25.7039, device='cuda:0'), 'best_accuracy_micro': tensor(0.6519, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      22, loss: 26.1795234680175781, accuracy-micro: 0.6518799662590027, accuracy-macro: 0.0000000000000000
# {'step': 23, 'best_loss_step': 23, 'best_accuracy_micro_step': 22, 'best_accuracy_macro_step': 0, 'loss': tensor(25.0440, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6474, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(25.0440, device='cuda:0'), 'best_accuracy_micro': tensor(0.6519, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      23, loss: 25.0440425872802734, accuracy-micro: 0.6473799943923950, accuracy-macro: 0.0000000000000000
# {'step': 24, 'best_loss_step': 24, 'best_accuracy_micro_step': 22, 'best_accuracy_macro_step': 0, 'loss': tensor(23.7726, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6479, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(23.7726, device='cuda:0'), 'best_accuracy_micro': tensor(0.6519, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      24, loss: 23.7725925445556641, accuracy-micro: 0.6479099988937378, accuracy-macro: 0.0000000000000000
# {'step': 25, 'best_loss_step': 25, 'best_accuracy_micro_step': 25, 'best_accuracy_macro_step': 0, 'loss': tensor(22.6229, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6611, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(22.6229, device='cuda:0'), 'best_accuracy_micro': tensor(0.6611, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      25, loss: 22.6228790283203125, accuracy-micro: 0.6611049771308899, accuracy-macro: 0.0000000000000000
# {'step': 26, 'best_loss_step': 26, 'best_accuracy_micro_step': 26, 'best_accuracy_macro_step': 0, 'loss': tensor(21.2892, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6718, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(21.2892, device='cuda:0'), 'best_accuracy_micro': tensor(0.6718, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      26, loss: 21.2892303466796875, accuracy-micro: 0.6718149781227112, accuracy-macro: 0.0000000000000000
# {'step': 27, 'best_loss_step': 26, 'best_accuracy_micro_step': 27, 'best_accuracy_macro_step': 0, 'loss': tensor(21.8883, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6728, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(21.2892, device='cuda:0'), 'best_accuracy_micro': tensor(0.6728, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      27, loss: 21.8883152008056641, accuracy-micro: 0.6727550029754639, accuracy-macro: 0.0000000000000000
# {'step': 28, 'best_loss_step': 28, 'best_accuracy_micro_step': 28, 'best_accuracy_macro_step': 0, 'loss': tensor(20.1509, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6813, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(20.1509, device='cuda:0'), 'best_accuracy_micro': tensor(0.6813, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      28, loss: 20.1509361267089844, accuracy-micro: 0.6812999844551086, accuracy-macro: 0.0000000000000000
# {'step': 29, 'best_loss_step': 28, 'best_accuracy_micro_step': 28, 'best_accuracy_macro_step': 0, 'loss': tensor(20.4753, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6797, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(20.1509, device='cuda:0'), 'best_accuracy_micro': tensor(0.6813, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      29, loss: 20.4752902984619141, accuracy-micro: 0.6796749830245972, accuracy-macro: 0.0000000000000000
# {'step': 30, 'best_loss_step': 28, 'best_accuracy_micro_step': 30, 'best_accuracy_macro_step': 0, 'loss': tensor(20.4673, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6862, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(20.1509, device='cuda:0'), 'best_accuracy_micro': tensor(0.6862, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      30, loss: 20.4672641754150391, accuracy-micro: 0.6862049698829651, accuracy-macro: 0.0000000000000000
# {'step': 31, 'best_loss_step': 31, 'best_accuracy_micro_step': 31, 'best_accuracy_macro_step': 0, 'loss': tensor(20.0670, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6902, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(20.0670, device='cuda:0'), 'best_accuracy_micro': tensor(0.6902, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      31, loss: 20.0669898986816406, accuracy-micro: 0.6902099847793579, accuracy-macro: 0.0000000000000000
# {'step': 32, 'best_loss_step': 31, 'best_accuracy_micro_step': 31, 'best_accuracy_macro_step': 0, 'loss': tensor(20.4642, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6872, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(20.0670, device='cuda:0'), 'best_accuracy_micro': tensor(0.6902, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      32, loss: 20.4642295837402344, accuracy-micro: 0.6872199773788452, accuracy-macro: 0.0000000000000000
# {'step': 33, 'best_loss_step': 31, 'best_accuracy_micro_step': 33, 'best_accuracy_macro_step': 0, 'loss': tensor(20.3419, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6920, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(20.0670, device='cuda:0'), 'best_accuracy_micro': tensor(0.6920, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      33, loss: 20.3419075012207031, accuracy-micro: 0.6920299530029297, accuracy-macro: 0.0000000000000000
# {'step': 34, 'best_loss_step': 34, 'best_accuracy_micro_step': 33, 'best_accuracy_macro_step': 0, 'loss': tensor(19.3802, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6863, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(19.3802, device='cuda:0'), 'best_accuracy_micro': tensor(0.6920, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      34, loss: 19.3802490234375000, accuracy-micro: 0.6862899661064148, accuracy-macro: 0.0000000000000000
# {'step': 35, 'best_loss_step': 34, 'best_accuracy_micro_step': 35, 'best_accuracy_macro_step': 0, 'loss': tensor(19.7370, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6981, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(19.3802, device='cuda:0'), 'best_accuracy_micro': tensor(0.6981, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      35, loss: 19.7369594573974609, accuracy-micro: 0.6980649828910828, accuracy-macro: 0.0000000000000000
# {'step': 36, 'best_loss_step': 34, 'best_accuracy_micro_step': 35, 'best_accuracy_macro_step': 0, 'loss': tensor(19.3883, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6964, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(19.3802, device='cuda:0'), 'best_accuracy_micro': tensor(0.6981, device='cuda:0'), 'best_accuracy_macro': 0}
# step:
device='cuda:0'), 'best_accuracy_macro': 0}
# step:      47, loss: 18.2210197448730469, accuracy-micro: 0.7283700108528137, accuracy-macro: 0.0000000000000000
# {'step': 48, 'best_loss_step': 47, 'best_accuracy_micro_step': 47, 'best_accuracy_macro_step': 0, 'loss': tensor(19.3423, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7205, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2210, device='cuda:0'), 'best_accuracy_micro': tensor(0.7284, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      48, loss: 19.3422622680664062, accuracy-micro: 0.7205149531364441, accuracy-macro: 0.0000000000000000
# {'step': 49, 'best_loss_step': 47, 'best_accuracy_micro_step': 49, 'best_accuracy_macro_step': 0, 'loss': tensor(18.5613, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7306, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2210, device='cuda:0'), 'best_accuracy_micro': tensor(0.7306, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      49, loss: 18.5613155364990234, accuracy-micro: 0.7306050062179565, accuracy-macro: 0.0000000000000000
# {'step': 50, 'best_loss_step': 47, 'best_accuracy_micro_step': 50, 'best_accuracy_macro_step': 0, 'loss': tensor(18.5289, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7328, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2210, device='cuda:0'), 'best_accuracy_micro': tensor(0.7328, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      50, loss: 18.5288600921630859, accuracy-micro: 0.7327649593353271, accuracy-macro: 0.0000000000000000
# {'step': 51, 'best_loss_step': 51, 'best_accuracy_micro_step': 50, 'best_accuracy_macro_step': 0, 'loss': tensor(17.9424, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7274, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(17.9424, device='cuda:0'), 'best_accuracy_micro': tensor(0.7328, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      51, loss: 17.9424057006835938, accuracy-micro: 0.7274399995803833, accuracy-macro: 0.0000000000000000
# {'step': 52, 'best_loss_step': 52, 'best_accuracy_micro_step': 50, 'best_accuracy_macro_step': 0, 'loss': tensor(17.6592, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7310, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(17.6592, device='cuda:0'), 'best_accuracy_micro': tensor(0.7328, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      52, loss: 17.6592178344726562, accuracy-micro: 0.7309550046920776, accuracy-macro: 0.0000000000000000
# {'step': 53, 'best_loss_step': 53, 'best_accuracy_micro_step': 50, 'best_accuracy_macro_step': 0, 'loss': tensor(17.5714, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7324, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(17.5714, device='cuda:0'), 'best_accuracy_micro': tensor(0.7328, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      53, loss: 17.5713748931884766, accuracy-micro: 0.7324099540710449, accuracy-macro: 0.0000000000000000
# {'step': 54, 'best_loss_step': 54, 'best_accuracy_micro_step': 50, 'best_accuracy_macro_step': 0, 'loss': tensor(17.3726, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7244, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(17.3726, device='cuda:0'), 'best_accuracy_micro': tensor(0.7328, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      54, loss: 17.3725967407226562, accuracy-micro: 0.7243799567222595, accuracy-macro: 0.0000000000000000
# {'step': 55, 'best_loss_step': 55, 'best_accuracy_micro_step': 50, 'best_accuracy_macro_step': 0, 'loss': tensor(17.0088, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7305, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(17.0088, device='cuda:0'), 'best_accuracy_micro': tensor(0.7328, device='cuda:0'), 'best_accuracy_macro': 0}
# step:      55, loss: 17.0088462829589844, accuracy-micro: 0.7305399775505066, accuracy-macro: 0.0000000000000000
# {'step': 56, 'best_loss_step': 55, 'best_accuracy_micro_step': 50, 'best_accuracy_macro_step': 0, 'loss': tensor(17.5744, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7242, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(17.0088, device='cuda:0'), 'best_accuracy_micro': tensor(0.7328, device='cuda:0'), 'best_accuracy_macro': 0}
# step:
device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7629, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     180, loss: 17.9106311798095703, accuracy-micro: 0.7629149556159973, accuracy-macro: 0.0000000000000000
# {'step': 181, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(17.5370, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7433, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     181, loss: 17.5369968414306641, accuracy-micro: 0.7432900071144104, accuracy-macro: 0.0000000000000000
# {'step': 182, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(17.6037, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7588, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     182, loss: 17.6036624908447266, accuracy-micro: 0.7588499784469604, accuracy-macro: 0.0000000000000000
# {'step': 183, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(17.5265, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7532, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     183, loss: 17.5265045166015625, accuracy-micro: 0.7531899809837341, accuracy-macro: 0.0000000000000000
# {'step': 184, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(17.3884, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7466, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     184, loss: 17.3884162902832031, accuracy-micro: 0.7466149926185608, accuracy-macro: 0.0000000000000000
# {'step': 185, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(16.8669, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7422, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     185, loss: 16.8669166564941406, accuracy-micro: 0.7421900033950806, accuracy-macro: 0.0000000000000000
# {'step': 186, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(14.3261, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7513, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     186, loss: 14.3260774612426758, accuracy-micro: 0.7513049840927124, accuracy-macro: 0.0000000000000000
# {'step': 187, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(21.1035, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6660, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     187, loss: 21.1034603118896484, accuracy-micro: 0.6659950017929077, accuracy-macro: 0.0000000000000000
# {'step': 188, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(18.2193, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7586, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     188, loss: 18.2192592620849609, accuracy-micro: 0.7585949897766113, accuracy-macro: 0.0000000000000000
# {'step': 189, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(19.4890, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6782, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     189, loss: 19.4890365600585938, accuracy-micro: 0.6781749725341797, accuracy-macro: 0.0000000000000000
# {'step': 190, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(22.3290, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6531, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     190, loss: 22.3289794921875000, accuracy-micro: 0.6530849933624268, accuracy-macro: 0.0000000000000000
# {'step': 191, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(24.2340, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6496, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     191, loss: 24.2339935302734375, accuracy-micro: 0.6495749950408936, accuracy-macro: 0.0000000000000000
# {'step': 192, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(26.4251, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6543, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     192, loss: 26.4251346588134766, accuracy-micro: 0.6543299555778503, accuracy-macro: 0.0000000000000000
# {'step': 193, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(27.7178, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6486, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     193, loss: 27.7178421020507812, accuracy-micro: 0.6485750079154968, accuracy-macro: 0.0000000000000000
# {'step': 194, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(29.2232, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6485, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     194, loss: 29.2232494354248047, accuracy-micro: 0.6485499739646912, accuracy-macro: 0.0000000000000000
# {'step': 195, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(30.2415, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6487, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     195, loss: 30.2415199279785156, accuracy-micro: 0.6486600041389465, accuracy-macro: 0.0000000000000000
# {'step': 196, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(29.6647, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6538, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     196, loss: 29.6647243499755859, accuracy-micro: 0.6537849903106689, accuracy-macro: 0.0000000000000000
# {'step': 197, 'best_loss_step': 176, 'best_accuracy_micro_step': 164, 'best_accuracy_macro_step': 0, 'loss': tensor(30.5409, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6482, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(9.5705, device='cuda:0'), 'best_accuracy_micro': tensor(0.7660, device='cuda:0'), 'best_accuracy_macro': 0}
# step:     197, loss: 30.5408821105957031, accuracy-micro: 0.6481649875640869, accuracy-macro: 0.0000000000000000

# %%
wandb.finish()

# %%
safe_state(run_checkpoint_path/'finish.chkpt', model, optimizer, dataloader, run_state)
