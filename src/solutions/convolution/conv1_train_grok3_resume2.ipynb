# %%
import sys
import torch
import wandb
from pathlib import Path
sys.path.append('../..')

from solutions.convolution.conv1_model import Conv1Model
from cgol.generator.uniform_density_generator import UniformDensityGenerator
from cgol.simulator.minimal_architecture_simulator import MinimalArchitectureSimulator
from cgol.dataloader.dataloader_2 import Dataloader2
from cgol.loss.completion_loss import CompletionLoss
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
checkpoint = torch.load('checkpoints_train_grok3_resume/final.chkpt')

# %%
seed = 0
width = 20
height = 20
batch_size = 100
dtype = torch.float
preprocess_device = 'cpu'
model_device = 'cuda'

simulator = MinimalArchitectureSimulator(device=preprocess_device, dtype=dtype)
generator = UniformDensityGenerator(seed, preprocess_device, dtype)
generator.rng.set_state(checkpoint['dataloader_state']['generator']['rng'])

dataloader = Dataloader2(generator, simulator, 
                         batch_size, width, height, 
                         preprocess_device, model_device, dtype, 
                         0.1, 150)
dataloader.last_batch = checkpoint['dataloader_state']['last_batch']
dataloader.sequence_ages = checkpoint['dataloader_state']['sequence_ages']
dataloader.step = checkpoint['dataloader_state']['step']

model = Conv1Model(device=model_device, dtype=dtype, n_channels=2000, n_hidden_layers=4)
model.load_state_dict(checkpoint['model_state'])

lr = 0.001
betas = (0.9,0.999)
eps = 0.00000001
weight_decay = 0
optimizer = torch.optim.Adam(model.parameters(), lr=lr, betas=betas, eps=eps, weight_decay=weight_decay)
optimizer.load_state_dict(checkpoint['optimizer_state'])

loss_fn = torch.nn.MSELoss()

config = {
    "dataloader": dataloader.get_config(),
    "model": model.get_config(),
    "optimizer": {
        "type": "Adam",
        "lr": lr,
        "betas": betas,
        "eps": eps,
        "weight_decay": weight_decay
    },
    "loss": {
        "type": "MSELoss"
    }
}

config
# Out:
# {'dataloader': {'type': 'Dataloader1',
#   'generator': {'type': 'UniformDensityGenerator', 'seed': 0},
#   'width': 20,
#   'height': 20,
#   'batch_size': 100,
#   'min_change_threshold': 0.1,
#   'max_sequence_age': 150},
#  'model': {'type': 'Conv1Model',
#   'is_toroidal': False,
#   'kernel_size': 5,
#   'activation': 'type',
#   'last_activation': 'type',
#   'n_hidden_layers': 4,
#   'n_channels': 2000,
#   'n_parameters': 102001,
#   'weight_init': 'xavier_uniform',
#   'bias_init': 'zeros_'},
#  'optimizer': {'type': 'Adam',
#   'lr': 0.001,
#   'betas': (0.9, 0.999),
#   'eps': 1e-08,
#   'weight_decay': 0},
#  'loss': {'type': 'MSELoss'}}

# %%
wandb_log = True

# %%
def safe_state(path: str, 
               model: torch.nn.Module, 
               optimizer: torch.nn.Module, 
               dataloader, 
               run_state: dict):
    save_state = {
        'model_state': model.state_dict(),
        'optimizer_state': optimizer.state_dict(),
        'dataloader_state': dataloader.get_state(),
        'run_state': run_state
    }
    torch.save(save_state, path)

def train(
        run_state: dict,
        model: torch.nn.Module, 
        dataloader, 
        optimizer: torch.optim.Optimizer, 
        loss_fn: torch.nn.Module, 
        checkpoint_path: Path, 
        max_steps: int=300000, 
        patience: int=75000) -> dict:
    run_state.update({
        'step': 0,
        'best_loss_step': 0,
        'best_accuracy_micro_step': 0,
        'best_accuracy_macro_step': 0,
        'loss': sys.float_info.max,
        'accuracy_micro': 0,
        'accuracy_macro': 0,
        'best_loss': sys.float_info.max,
        'best_accuracy_micro': 0,
        'best_accuracy_macro': 0
    } | run_state)
    do_train = True

    safe_state(checkpoint_path/'initial.ckpt', model, optimizer, dataloader, run_state)
    
    if wandb_log:
        wandb.init('llottenbach', 'cgol', resume='allow', resume_from=run_state['step'], id='lh6vi61e')

    model.train()
    try:
        batch = next(dataloader)
        new_batch = True
        
        while do_train:
            logs = {}
            optimizer.zero_grad()
            output = model.forward(batch[0])

            # metrics
            run_state['loss'] = loss_fn(output, batch[1])
            run_state['accuracy_micro'] = (((output >= 0.5) == batch[1]).sum()
                / (output.shape[0] * output.shape[1] * output.shape[2]))
            run_state['accuracy_macro'] = (((output >= 0.5) == batch[1]).all((-1,-2)).sum()
                / (output.shape[0]))
            
            # optimize
            run_state['loss'].backward()
            optimizer.step()
            
            if new_batch:
                # update highscore
                if run_state['best_loss'] > run_state['loss']:
                    run_state['best_loss'] = run_state['loss'].detach().clone()
                    run_state['best_loss_step'] = run_state['step']
                    safe_state(checkpoint_path/'best_loss.chkpt', model, optimizer, dataloader, run_state)
                if run_state['best_accuracy_micro'] < run_state['accuracy_micro']:
                    run_state['best_accuracy_micro'] = run_state['accuracy_micro'].detach().clone()
                    run_state['best_accuracy_micro_step'] = run_state['step']
                    safe_state(checkpoint_path/'best_acc_micro.chkpt', model, optimizer, dataloader, run_state)
                if run_state['best_accuracy_macro'] < run_state['accuracy_macro']:
                    run_state['best_accuracy_macro'] = run_state['accuracy_macro'].detach().clone()
                    run_state['best_accuracy_macro_step'] = run_state['step']
                    safe_state(checkpoint_path/'best_acc_macro.chkpt', model, optimizer, dataloader, run_state)

                # log
                logs = logs | {
                    'train/first_encounter/loss': run_state['loss'],
                    'train/first_encounter/accuracy_micro': run_state['accuracy_micro'],
                    'train/first_encounter/accuracy_macro': run_state['accuracy_macro'],
                    'dataloader/step': dataloader.step,
                    'dataloader/batch_age/min': dataloader.sequence_ages.min(),
                    'dataloader/batch_age/max': dataloader.sequence_ages.max(),
                    'dataloader/batch_age/median': dataloader.sequence_ages.float().median(),
                    'dataloader/batch_age/mean': dataloader.sequence_ages.float().mean(),
                    'dataloader/batch_age/std': dataloader.sequence_ages.float().std(),
                    'dataloader/batch_diffs_per_cell/min': dataloader.batch_diffs_per_cell.min(),
                    'dataloader/batch_diffs_per_cell/max': dataloader.batch_diffs_per_cell.max(),
                    'dataloader/batch_diffs_per_cell/median': dataloader.batch_diffs_per_cell.median(),
                    'dataloader/batch_diffs_per_cell/mean': dataloader.batch_diffs_per_cell.mean(),
                    'dataloader/batch_diffs_per_cell/std': dataloader.batch_diffs_per_cell.std(),
                }
            
            # new batch condition
            new_batch = False
            if run_state['accuracy_macro'] >= .5:
                batch = next(dataloader)
                new_batch = True

            # stop condition
            if (max_steps <= run_state['step']
                or run_state['best_loss_step'] + patience <= run_state['step']
                or run_state['best_accuracy_micro_step'] + patience <= run_state['step']
                or run_state['best_accuracy_macro_step'] + patience <= run_state['step']):
                do_train = False

            # SPLIT UP
            # log
            print(run_state)
            print(f'step: {run_state["step"]:7d},',
                f'loss: {run_state["loss"]:1.16f},',
                f'accuracy-micro: {run_state["accuracy_micro"]:1.16f},',
                f'accuracy-macro: {run_state["accuracy_macro"]:1.16f}')
            logs = logs | {
                'train/loss': run_state['loss'],
                'train/accuracy-micro': run_state['accuracy_micro'],
                'train/accuracy-macro': run_state['accuracy_macro']
            }
            
            if wandb_log:
                wandb.log(logs, run_state['step'])

            if do_train:
                run_state['step'] += 1
            else:
                safe_state(checkpoint_path/'stop.chkpt', model, optimizer, dataloader, run_state)
    except BaseException as e:
        safe_state(checkpoint_path/'error.chkpt', model, optimizer, dataloader, run_state)
        raise e

    return run_state

# %%
if wandb_log:
    wandb.login()
# bigger model
# slight weight decay

# new loss function
#
# Out:
# wandb: Currently logged in as: lukas-lottenbach (llottenbach-nlp) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
run_checkpoint_path = Path('checkpoints_train_grok3_resume2')
run_checkpoint_path.mkdir(exist_ok=True)
run_state = checkpoint['run_state']
run_state = train(run_state, model, dataloader, optimizer, loss_fn, run_checkpoint_path)
# Out:
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/workspaces/cgol/src/solutions/convolution/wandb/run-20251206_211855-lh6vi61e</code>
# Resuming run <strong><a href='https://wandb.ai/llottenbach/cgol/runs/lh6vi61e' target="_blank">stilted-snow-17</a></strong> to <a href='https://wandb.ai/llottenbach/cgol' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/llottenbach/cgol' target="_blank">https://wandb.ai/llottenbach/cgol</a>
#  View run at <a href='https://wandb.ai/llottenbach/cgol/runs/lh6vi61e' target="_blank">https://wandb.ai/llottenbach/cgol/runs/lh6vi61e</a>
# {'step': 26668, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2972, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.6935, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26668, loss: 0.2971531152725220, accuracy-micro: 0.6935499906539917, accuracy-macro: 0.0000000000000000
# {'step': 26669, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2927, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7019, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26669, loss: 0.2927400767803192, accuracy-micro: 0.7019249796867371, accuracy-macro: 0.0000000000000000
# {'step': 26670, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7068, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26670, loss: 0.2905330359935760, accuracy-micro: 0.7067750096321106, accuracy-macro: 0.0000000000000000
# {'step': 26671, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2901, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7088, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26671, loss: 0.2901466488838196, accuracy-micro: 0.7087500095367432, accuracy-macro: 0.0000000000000000
# {'step': 26672, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2903, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7091, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26672, loss: 0.2902645766735077, accuracy-micro: 0.7091249823570251, accuracy-macro: 0.0000000000000000
# {'step': 26673, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2904, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7093, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26673, loss: 0.2903614044189453, accuracy-micro: 0.7092999815940857, accuracy-macro: 0.0000000000000000
# {'step': 26674, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2904, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26674, loss: 0.2904363274574280, accuracy-micro: 0.7093999981880188, accuracy-macro: 0.0000000000000000
# {'step': 26675, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26675, loss: 0.2904787659645081, accuracy-micro: 0.7093749642372131, accuracy-macro: 0.0000000000000000
# {'step': 26676, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26676, loss: 0.2905049622058868, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26677, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26677, loss: 0.2905230820178986, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26678, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26678, loss: 0.2905352711677551, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26679, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26679, loss: 0.2905433475971222, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26680, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26680, loss: 0.2905487716197968, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26681, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26681, loss: 0.2905526161193848, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26682, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26682, loss: 0.2905553281307220, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26683, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26683, loss: 0.2905574142932892, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26684, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26684, loss: 0.2905589640140533, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26685, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26685, loss: 0.2905601561069489, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26686, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26686, loss: 0.2905611395835876, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26687, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26687, loss: 0.2905618548393250, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26688, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26688, loss: 0.2905624508857727, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26689, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26689, loss: 0.2905628979206085, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26690, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26690, loss: 0.2905632853507996, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26691, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26691, loss: 0.2905635535717010, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26692, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26692, loss: 0.2905638217926025, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26693, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26693, loss: 0.2905640006065369, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26694, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26694, loss: 0.2905641198158264, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26695, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26695, loss: 0.2905642092227936, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26696, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26696, loss: 0.2905642986297607, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26697, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26697, loss: 0.2905642986297607, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26698, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26698, loss: 0.2905643582344055, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26699, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26699, loss: 0.2905642986297607, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26700, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26700, loss: 0.2905642390251160, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26701, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26701, loss: 0.2905642092227936, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26702, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26702, loss: 0.2905641198158264, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26703, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26703, loss: 0.2905640602111816, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26704, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26704, loss: 0.2905639410018921, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26705, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26705, loss: 0.2905638217926025, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26706, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26706, loss: 0.2905636727809906, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26707, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26707, loss: 0.2905635237693787, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26708, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26708, loss: 0.2905633747577667, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26709, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26709, loss: 0.2905631661415100, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26710, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26710, loss: 0.2905629873275757, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26711, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26711, loss: 0.2905627787113190, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26712, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26712, loss: 0.2905625402927399, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26713, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26713, loss: 0.2905623316764832, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26714, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26714, loss: 0.2905620634555817, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26715, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26715, loss: 0.2905617952346802, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26716, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26716, loss: 0.2905615270137787, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26717, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26717, loss: 0.2905612587928772, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26718, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26718, loss: 0.2905609607696533, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26719, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26719, loss: 0.2905606031417847, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26720, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26720, loss: 0.2905602455139160, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26721, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26721, loss: 0.2905599176883698, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26722, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26722, loss: 0.2905595004558563, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26723, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26723, loss: 0.2905590832233429, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26724, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26724, loss: 0.2905586361885071, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26725, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26725, loss: 0.2905581593513489, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26726, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26726, loss: 0.2905576527118683, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26727, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26727, loss: 0.2905571162700653, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26728, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26728, loss: 0.2905565500259399, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26729, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26729, loss: 0.2905559539794922, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26730, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26730, loss: 0.2905552983283997, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26731, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26731, loss: 0.2905545830726624, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26732, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26732, loss: 0.2905538082122803, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26733, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26733, loss: 0.2905530333518982, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26734, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26734, loss: 0.2905521392822266, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26735, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26735, loss: 0.2905511558055878, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26736, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2906, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26736, loss: 0.2905501127243042, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26737, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26737, loss: 0.2905489802360535, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26738, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26738, loss: 0.2905477285385132, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26739, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26739, loss: 0.2905463278293610, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26740, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26740, loss: 0.2905448079109192, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26741, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26741, loss: 0.2905431091785431, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26742, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26742, loss: 0.2905412018299103, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26743, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26743, loss: 0.2905390560626984, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26744, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26744, loss: 0.2905366122722626, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26745, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26745, loss: 0.2905338406562805, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26746, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26746, loss: 0.2905306518077850, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26747, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26747, loss: 0.2905269563198090, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26748, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26748, loss: 0.2905226349830627, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26749, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26749, loss: 0.2905175089836121, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26750, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26750, loss: 0.2905114293098450, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26751, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26751, loss: 0.2905040979385376, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26752, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26752, loss: 0.2904953062534332, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26753, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26753, loss: 0.2904848456382751, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26754, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26754, loss: 0.2904724478721619, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26755, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2905, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7094, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26755, loss: 0.2904582321643829, accuracy-micro: 0.7094249725341797, accuracy-macro: 0.0000000000000000
# {'step': 26756, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2904, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7095, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26756, loss: 0.2904421687126160, accuracy-micro: 0.7094500064849854, accuracy-macro: 0.0000000000000000
# {'step': 26757, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2904, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7095, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26757, loss: 0.2904244959354401, accuracy-micro: 0.7094500064849854, accuracy-macro: 0.0000000000000000
# {'step': 26758, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2904, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7095, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26758, loss: 0.2904050946235657, accuracy-micro: 0.7094749808311462, accuracy-macro: 0.0000000000000000
# {'step': 26759, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.2904, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.7095, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   26759, loss: 0.2903835773468018, accuracy-micro: 0.7094999551773071, accuracy-macro: 0.0000000000000000
# ...
# step:   31169, loss: 0.0493337400257587, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31170, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31170, loss: 0.0493300892412663, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31171, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31171, loss: 0.0493288636207581, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31172, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31172, loss: 0.0493282154202461, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31173, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31173, loss: 0.0493274815380573, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31174, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31174, loss: 0.0493264868855476, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31175, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31175, loss: 0.0493253581225872, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31176, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31176, loss: 0.0493243858218193, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31177, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31177, loss: 0.0493233054876328, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31178, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31178, loss: 0.0493221841752529, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31179, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31179, loss: 0.0493208318948746, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31180, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31180, loss: 0.0493192262947559, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31181, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31181, loss: 0.0493172779679298, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31182, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31182, loss: 0.0493152327835560, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31183, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31183, loss: 0.0493126511573792, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31184, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31184, loss: 0.0493091046810150, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31185, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31185, loss: 0.0493038147687912, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31186, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31186, loss: 0.0492955073714256, accuracy-micro: 0.9508000016212463, accuracy-macro: 0.0099999997764826
# {'step': 31187, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31187, loss: 0.0492845922708511, accuracy-micro: 0.9508249759674072, accuracy-macro: 0.0099999997764826
# {'step': 31188, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31188, loss: 0.0492742806673050, accuracy-micro: 0.9508249759674072, accuracy-macro: 0.0099999997764826
# {'step': 31189, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31189, loss: 0.0492674149572849, accuracy-micro: 0.9508499503135681, accuracy-macro: 0.0099999997764826
# {'step': 31190, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31190, loss: 0.0492648370563984, accuracy-micro: 0.9508499503135681, accuracy-macro: 0.0099999997764826
# {'step': 31191, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31191, loss: 0.0492628663778305, accuracy-micro: 0.9508499503135681, accuracy-macro: 0.0099999997764826
# {'step': 31192, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31192, loss: 0.0492604486644268, accuracy-micro: 0.9508499503135681, accuracy-macro: 0.0099999997764826
# {'step': 31193, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31193, loss: 0.0492564402520657, accuracy-micro: 0.9508499503135681, accuracy-macro: 0.0099999997764826
# {'step': 31194, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9508, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31194, loss: 0.0492502488195896, accuracy-micro: 0.9508499503135681, accuracy-macro: 0.0099999997764826
# {'step': 31195, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0492, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9509, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31195, loss: 0.0492431558668613, accuracy-micro: 0.9508749842643738, accuracy-macro: 0.0099999997764826
# {'step': 31196, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0492, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9509, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31196, loss: 0.0492384247481823, accuracy-micro: 0.9508749842643738, accuracy-macro: 0.0099999997764826
# {'step': 31197, 'best_loss_step': 0, 'best_accuracy_micro_step': 26668, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0492, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9509, device='cuda:0'), 'accuracy_macro': tensor(0.0100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.6935, device='cuda:0'), 'best_accuracy_macro': 0}
# step:   31197, loss: 0.0492351017892361, accuracy-micro: 0.9508749842643738, accuracy-macro: 0.0099999997764826
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_834673/1471168858.py in <cell line: 0>()
#       2 run_checkpoint_path.mkdir(exist_ok=True)
#       3 run_state = checkpoint['run_state']
# ----> 4 run_state = train(run_state, model, dataloader, optimizer, loss_fn, run_checkpoint_path)
#
# /tmp/ipykernel_834673/590189872.py in train(run_state, model, dataloader, optimizer, loss_fn, checkpoint_path, max_steps, patience)
#     129     except BaseException as e:
#     130         safe_state(checkpoint_path/'error.chkpt', model, optimizer, dataloader, run_state)
# --> 131         raise e
#     132
#     133     return run_state
#
# /tmp/ipykernel_834673/590189872.py in train(run_state, model, dataloader, optimizer, loss_fn, checkpoint_path, max_steps, patience)
#     109             # SPLIT UP
#     110             # log
# --> 111             print(run_state)
#     112             print(f'step: {run_state["step"]:7d},',
#     113                 f'loss: {run_state["loss"]:1.16f},',
#
# KeyboardInterrupt:

# %%
safe_state(run_checkpoint_path/'final.chkpt', model, optimizer, dataloader, run_state)

# %%
print(run_state)
# Out:
# {'step': 9911, 'best_loss_step': 0, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward0>), 'accuracy_micro': tensor(0.9968, device='cuda:0'), 'accuracy_macro': tensor(0.6100, device='cuda:0'), 'best_loss': tensor(0.2501, device='cuda:0'), 'best_accuracy_micro': tensor(0.5182, device='cuda:0'), 'best_accuracy_macro': 0}

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>dataloader/batch_age/max</td><td>▁</td></tr><tr><td>dataloader/batch_age/mean</td><td>▁</td></tr><tr><td>dataloader/batch_age/median</td><td>▁</td></tr><tr><td>dataloader/batch_age/min</td><td>▁</td></tr><tr><td>dataloader/batch_age/std</td><td>▁</td></tr><tr><td>dataloader/batch_diffs_per_cell/max</td><td>▁</td></tr><tr><td>dataloader/batch_diffs_per_cell/mean</td><td>▁</td></tr><tr><td>dataloader/batch_diffs_per_cell/median</td><td>▁</td></tr><tr><td>dataloader/batch_diffs_per_cell/min</td><td>▁</td></tr><tr><td>dataloader/batch_diffs_per_cell/std</td><td>▁</td></tr><tr><td>dataloader/step</td><td>▁</td></tr><tr><td>train/accuracy-macro</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁██████████████████</td></tr><tr><td>train/accuracy-micro</td><td>▁▂▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇██████████████████</td></tr><tr><td>train/first_encounter/accuracy_macro</td><td>▁</td></tr><tr><td>train/first_encounter/accuracy_micro</td><td>▁</td></tr><tr><td>train/first_encounter/loss</td><td>▁</td></tr><tr><td>train/loss</td><td>██▅▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>dataloader/batch_age/max</td><td>3</td></tr><tr><td>dataloader/batch_age/mean</td><td>2.26</td></tr><tr><td>dataloader/batch_age/median</td><td>3</td></tr><tr><td>dataloader/batch_age/min</td><td>1</td></tr><tr><td>dataloader/batch_age/std</td><td>0.84829</td></tr><tr><td>dataloader/batch_diffs_per_cell/max</td><td>0.7425</td></tr><tr><td>dataloader/batch_diffs_per_cell/mean</td><td>0.2618</td></tr><tr><td>dataloader/batch_diffs_per_cell/median</td><td>0.23</td></tr><tr><td>dataloader/batch_diffs_per_cell/min</td><td>0.1</td></tr><tr><td>dataloader/batch_diffs_per_cell/std</td><td>0.13619</td></tr><tr><td>dataloader/step</td><td>3</td></tr><tr><td>train/accuracy-macro</td><td>0.01</td></tr><tr><td>train/accuracy-micro</td><td>0.95087</td></tr><tr><td>train/first_encounter/accuracy_macro</td><td>0</td></tr><tr><td>train/first_encounter/accuracy_micro</td><td>0.69355</td></tr><tr><td>train/first_encounter/loss</td><td>0.29715</td></tr><tr><td>train/loss</td><td>0.04924</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stilted-snow-17</strong> at: <a href='https://wandb.ai/llottenbach/cgol/runs/lh6vi61e' target="_blank">https://wandb.ai/llottenbach/cgol/runs/lh6vi61e</a><br> View project at: <a href='https://wandb.ai/llottenbach/cgol' target="_blank">https://wandb.ai/llottenbach/cgol</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251206_211855-lh6vi61e/logs</code>
