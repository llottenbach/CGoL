# %%
import sys
import torch
import wandb
from pathlib import Path
sys.path.append('../..')

from solutions.convolution.conv1_model import Conv1Model
from cgol.generator.uniform_density_generator import UniformDensityGenerator
from cgol.simulator.minimal_architecture_simulator import MinimalArchitectureSimulator
from cgol.dataloader.dataloader_2 import Dataloader2
from cgol.loss.completion_loss import CompletionLoss
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
seed = 0
width = 20
height = 20
batch_size = 1000
dtype = torch.float
preprocess_device = 'cpu'
model_device = 'cuda'

simulator = MinimalArchitectureSimulator(device=preprocess_device, dtype=dtype)
generator = UniformDensityGenerator(seed, preprocess_device, dtype)
dataloader = Dataloader2(generator, simulator, batch_size, width, height, preprocess_device, model_device, dtype, 0.1)

model = Conv1Model(device=model_device, dtype=dtype, n_hidden_layers=4, n_channels=1000)
model.initialize()
lr = 0.001
betas = (0.9,0.999)
eps = 0.00000001
weight_decay = 0.0001
optimizer = torch.optim.Adam(model.parameters(), lr=lr, betas=betas, eps=eps, weight_decay=weight_decay)
loss_fn = CompletionLoss()

config = {
    "dataloader": dataloader.get_config(),
    "model": model.get_config(),
    "optimizer": {
        "type": "Adam",
        "lr": lr,
        "betas": betas,
        "eps": eps,
        "weight_decay": weight_decay
    },
    "loss": {
        "type": "CompletionLoss"
    }
}

config
# Out:
# /workspaces/cgol/src/solutions/convolution/../../solutions/convolution/conv1_model.py:73: FutureWarning: `nn.init.xavier_uniform` is now deprecated in favor of `nn.init.xavier_uniform_`.
#   init_weight_f(self.conv_start.weight)
# /workspaces/cgol/src/solutions/convolution/../../solutions/convolution/conv1_model.py:76: FutureWarning: `nn.init.xavier_uniform` is now deprecated in favor of `nn.init.xavier_uniform_`.
#   init_weight_f(hidden_conf.weight)
# /workspaces/cgol/src/solutions/convolution/../../solutions/convolution/conv1_model.py:78: FutureWarning: `nn.init.xavier_uniform` is now deprecated in favor of `nn.init.xavier_uniform_`.
#   init_weight_f(self.conv_end.weight)
# {'dataloader': {'type': 'Dataloader1',
#   'generator': {'type': 'UniformDensityGenerator', 'seed': 0},
#   'width': 20,
#   'height': 20,
#   'batch_size': 1000,
#   'min_change_threshold': 0.1,
#   'max_sequence_age': 150},
#  'model': {'type': 'Conv1Model',
#   'is_toroidal': False,
#   'kernel_size': 5,
#   'activation': 'type',
#   'last_activation': 'type',
#   'n_hidden_layers': 4,
#   'n_channels': 1000,
#   'n_parameters': 51001,
#   'weight_init': 'xavier_uniform',
#   'bias_init': 'zeros_'},
#  'optimizer': {'type': 'Adam',
#   'lr': 0.001,
#   'betas': (0.9, 0.999),
#   'eps': 1e-08,
#   'weight_decay': 0.0001},
#  'loss': {'type': 'CompletionLoss'}}

# %%
wandb_log = True

# %%
def safe_state(path: str, 
               model: torch.nn.Module, 
               optimizer: torch.nn.Module, 
               dataloader, 
               run_state: dict):
    save_state = {
        'model_state': model.state_dict(),
        'optimizer_state': optimizer.state_dict(),
        'dataloader_state': dataloader.get_state(),
        'run_state': run_state
    }
    torch.save(save_state, path)

def train(
        run_state: dict,
        model: torch.nn.Module, 
        dataloader, 
        optimizer: torch.optim.Optimizer, 
        loss_fn: torch.nn.Module, 
        checkpoint_path: Path, 
        max_steps: int=300000, 
        patience: int=75000) -> dict:
    run_state.update({
        'step': 0,
        'best_loss_step': 0,
        'best_accuracy_micro_step': 0,
        'best_accuracy_macro_step': 0,
        'loss': sys.float_info.max,
        'accuracy_micro': 0,
        'accuracy_macro': 0,
        'best_loss': sys.float_info.max,
        'best_accuracy_micro': 0,
        'best_accuracy_macro': 0
    } | run_state)

    safe_state(checkpoint_path/'initial.ckpt', model, optimizer, dataloader, run_state)
    
    if wandb_log:
        wandb.init('llottenbach', 'cgol', config={
            "config": config
        })

    model.train()
    try:
        for batch in dataloader:
            optimizer.zero_grad()
            output = model.forward(batch[0])

            # metrics
            run_state['loss'] = loss_fn(output, batch[1])
            run_state['accuracy_micro'] = (((output >= 0.5) == batch[1]).sum()
                / (output.shape[0] * output.shape[1] * output.shape[2]))
            run_state['accuracy_macro'] = (((output >= 0.5) == batch[1]).all((-1,-2)).sum()
                / (output.shape[0]))
            
            if run_state['best_loss'] > run_state['loss']:
                run_state['best_loss'] = run_state['loss'].clone().detach()
                run_state['best_loss_step'] = run_state['step']
                safe_state(checkpoint_path/'best_loss.chkpt', model, optimizer, dataloader, run_state)
            if run_state['best_accuracy_micro'] < run_state['accuracy_micro']:
                run_state['best_accuracy_micro'] = run_state['accuracy_micro'].detach().clone()
                run_state['best_accuracy_micro_step'] = run_state['step']
                safe_state(checkpoint_path/'best_acc_micro.chkpt', model, optimizer, dataloader, run_state)
            if run_state['best_accuracy_macro'] < run_state['accuracy_macro']:
                run_state['best_accuracy_macro'] = run_state['accuracy_macro'].detach().clone()
                run_state['best_accuracy_macro_step'] = run_state['step']
                safe_state(checkpoint_path/'best_acc_macro.chkpt', model, optimizer, dataloader, run_state)
            
            # optimize
            run_state['loss'].backward()
            optimizer.step()
            
            # log
            print(run_state)
            print(f'step: {run_state["step"]:7d},',
                f'loss: {run_state["loss"]:1.16f},',
                f'accuracy-micro: {run_state["accuracy_micro"]:1.16f},',
                f'accuracy-macro: {run_state["accuracy_macro"]:1.16f}')
            if wandb_log:
                wandb.log({
                    'train/loss': run_state['loss'],
                    'train/accuracy-micro': run_state['accuracy_micro'],
                    'train/accuracy-macro': run_state['accuracy_macro'],
                    # dataloader
                    'dataloader/batch_age/min': dataloader.sequence_ages.min(),
                    'dataloader/batch_age/max': dataloader.sequence_ages.max(),
                    'dataloader/batch_age/median': dataloader.sequence_ages.float().median(),
                    'dataloader/batch_age/mean': dataloader.sequence_ages.float().mean(),
                    'dataloader/batch_age/std': dataloader.sequence_ages.float().std(),
                    'dataloader/batch_diffs_per_cell/min': dataloader.batch_diffs_per_cell.min(),
                    'dataloader/batch_diffs_per_cell/max': dataloader.batch_diffs_per_cell.max(),
                    'dataloader/batch_diffs_per_cell/median': dataloader.batch_diffs_per_cell.median(),
                    'dataloader/batch_diffs_per_cell/mean': dataloader.batch_diffs_per_cell.mean(),
                    'dataloader/batch_diffs_per_cell/std': dataloader.batch_diffs_per_cell.std(),
                },
                run_state['step'])

            # stop condition
            if (max_steps <= run_state['step']
                or run_state['best_loss_step'] + patience <= run_state['step']
                or run_state['best_accuracy_micro_step'] + patience <= run_state['step']
                or run_state['best_accuracy_macro_step'] + patience <= run_state['step']):

                safe_state(checkpoint_path/'stop.chkpt', model, optimizer, dataloader, run_state)
                break
            
            run_state['step'] += 1
    except Exception as e:
        safe_state(checkpoint_path/'error.chkpt', model, optimizer, dataloader, run_state)
        raise e

    return run_state

# %%
if wandb_log:
    wandb.login()
# Out:
# wandb: Currently logged in as: lukas-lottenbach (llottenbach-nlp) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
run_checkpoint_path = Path('conv1_train2')
run_checkpoint_path.mkdir(exist_ok=True)
run_state = {}
train(run_state, model, dataloader, optimizer, loss_fn, run_checkpoint_path)
# Out:
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/workspaces/cgol/src/solutions/convolution/wandb/run-20251130_144527-r9q9xxld</code>
# Syncing run <strong><a href='https://wandb.ai/llottenbach/cgol/runs/r9q9xxld' target="_blank">iconic-sunset-15</a></strong> to <a href='https://wandb.ai/llottenbach/cgol' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/llottenbach/cgol' target="_blank">https://wandb.ai/llottenbach/cgol</a>
#  View run at <a href='https://wandb.ai/llottenbach/cgol/runs/r9q9xxld' target="_blank">https://wandb.ai/llottenbach/cgol/runs/r9q9xxld</a>
# {'step': 0, 'best_loss_step': 0, 'best_accuracy_micro_step': 0, 'best_accuracy_macro_step': 0, 'loss': tensor(24.9971, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.4672, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(24.9971, device='cuda:0'), 'best_accuracy_micro': tensor(0.4672, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       0, loss: 24.9970989227294922, accuracy-micro: 0.4672249853610992, accuracy-macro: 0.0000000000000000
# {'step': 1, 'best_loss_step': 1, 'best_accuracy_micro_step': 1, 'best_accuracy_macro_step': 0, 'loss': tensor(24.3667, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6420, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(24.3667, device='cuda:0'), 'best_accuracy_micro': tensor(0.6420, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       1, loss: 24.3666744232177734, accuracy-micro: 0.6419799923896790, accuracy-macro: 0.0000000000000000
# {'step': 2, 'best_loss_step': 2, 'best_accuracy_micro_step': 2, 'best_accuracy_macro_step': 0, 'loss': tensor(23.2796, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6778, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(23.2796, device='cuda:0'), 'best_accuracy_micro': tensor(0.6778, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       2, loss: 23.2795886993408203, accuracy-micro: 0.6777650117874146, accuracy-macro: 0.0000000000000000
# {'step': 3, 'best_loss_step': 3, 'best_accuracy_micro_step': 3, 'best_accuracy_macro_step': 0, 'loss': tensor(21.7575, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.6992, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(21.7575, device='cuda:0'), 'best_accuracy_micro': tensor(0.6992, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       3, loss: 21.7574939727783203, accuracy-micro: 0.6992399692535400, accuracy-macro: 0.0000000000000000
# {'step': 4, 'best_loss_step': 4, 'best_accuracy_micro_step': 4, 'best_accuracy_macro_step': 0, 'loss': tensor(19.9384, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7265, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(19.9384, device='cuda:0'), 'best_accuracy_micro': tensor(0.7265, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       4, loss: 19.9384098052978516, accuracy-micro: 0.7264924645423889, accuracy-macro: 0.0000000000000000
# {'step': 5, 'best_loss_step': 5, 'best_accuracy_micro_step': 5, 'best_accuracy_macro_step': 0, 'loss': tensor(18.2126, device='cuda:0', grad_fn=<DivBackward0>), 'accuracy_micro': tensor(0.7421, device='cuda:0'), 'accuracy_macro': tensor(0., device='cuda:0'), 'best_loss': tensor(18.2126, device='cuda:0'), 'best_accuracy_micro': tensor(0.7421, device='cuda:0'), 'best_accuracy_macro': 0}
# step:       5, loss: 18.2125873565673828, accuracy-micro: 0.7420874834060669, accuracy-macro: 0.0000000000000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_452615/2202877177.py in <cell line: 0>()
#       2 run_checkpoint_path.mkdir(exist_ok=True)
#       3 run_state = {}
# ----> 4 train(run_state, model, dataloader, optimizer, loss_fn, run_checkpoint_path)
#       5
#       6 # max batch age 150
#
# /tmp/ipykernel_452615/2664927201.py in train(run_state, model, dataloader, optimizer, loss_fn, checkpoint_path, max_steps, patience)
#      72
#      73             # log
# ---> 74             print(run_state)
#      75             print(f'step: {run_state["step"]:7d},',
#      76                 f'loss: {run_state["loss"]:1.16f},',
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in __repr__(self, tensor_contents)
#     566             )
#     567         # All strings are unicode in Python 3.
# --> 568         return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#     569
#     570     def backward(
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor_str.py in _str(self, tensor_contents)
#     702     with torch.no_grad(), torch.utils._python_dispatch._disable_current_modes():
#     703         guard = torch._C._DisableFuncTorch()
# --> 704         return _str_intern(self, tensor_contents=tensor_contents)
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor_str.py in _str_intern(inp, tensor_contents)
#     619                         tensor_str = _tensor_str(self.to_dense(), indent)
#     620                     else:
# --> 621                         tensor_str = _tensor_str(self, indent)
#     622
#     623     if self.layout != torch.strided:
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor_str.py in _tensor_str(self, indent)
#     351         )
#     352     else:
# --> 353         formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     354         return _tensor_str_with_formatter(self, indent, summarize, formatter)
#     355
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor_str.py in __init__(self, tensor)
#     143
#     144         else:
# --> 145             nonzero_finite_vals = torch.masked_select(
#     146                 tensor_view, torch.isfinite(tensor_view) & tensor_view.ne(0)
#     147             )
#
# KeyboardInterrupt:
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x72a06c8a2e10>> (for post_run_cell):
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/wandb_init.py in _post_run_cell_hook(self, *args, **kwargs)
#     591
#     592         self._logger.info("resuming backend")
# --> 593         self.backend.interface.publish_resume()
#     594
#     595     def _jupyter_teardown(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface.py in publish_resume(self)
#     785     def publish_resume(self) -> None:
#     786         resume = pb.ResumeRequest()
# --> 787         self._publish_resume(resume)
#     788
#     789     @abstractmethod
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface_shared.py in _publish_resume(self, resume)
#     292     def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     293         rec = self._make_request(resume=resume)
# --> 294         self._publish(rec)
#     295
#     296     def _publish_run(self, run: pb.RunRecord) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/interface/interface_sock.py in _publish(self, record, local)
#      37     def _publish(self, record: "pb.Record", local: Optional[bool] = None) -> None:
#      38         self._assign(record)
# ---> 39         self._sock_client.send_record_publish(record)
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in send_record_publish(self, record)
#     168         server_req.request_id = record.control.mailbox_slot
#     169         server_req.record_publish.CopyFrom(record)
# --> 170         self.send_server_request(server_req)
#     171
#     172     def _extract_packet_bytes(self) -> Optional[bytes]:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in send_server_request(self, msg)
#     148
#     149     def send_server_request(self, msg: spb.ServerRequest) -> None:
# --> 150         self._send_message(msg)
#     151
#     152     def send_server_response(self, msg: spb.ServerResponse) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in _send_message(self, msg)
#     145         header = struct.pack("<BI", ord("W"), raw_size)
#     146         with self._lock:
# --> 147             self._sendall_with_error_handle(header + data)
#     148
#     149     def send_server_request(self, msg: spb.ServerRequest) -> None:
#
# /usr/local/lib/python3.11/dist-packages/wandb/sdk/lib/sock_client.py in _sendall_with_error_handle(self, data)
#     124             start_time = time.monotonic()
#     125             try:
# --> 126                 sent = self._sock.send(data)
#     127                 # sent equal to 0 indicates a closed socket
#     128                 if sent == 0:
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
wandb.finish()
safe_state(run_checkpoint_path/'finish.chkpt', model, optimizer, dataloader, run_state)
